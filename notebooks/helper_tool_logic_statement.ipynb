# %%
import anthropic
import os
from dotenv import load_dotenv
import openai

load_dotenv(".env")
# Out:
# False

# %%
def get_step_1_text(topic):
    return f"""
    You are an expert medical doctor with a specialty in {topic}. You have specifically been the final arbiter for managing prior authorizations for decades.
    I have a medical guideline from an insurance provider, written in markdown. The guidelines lay out all of the criteria by which a procedure or often multiple procedures might be considered "medically necessary". There are usually multiple paths that will yield this result.
    You will be hiring a team of medical interns to help you perform more prior authorizations accurately. Your task is to make these medical guidelines as simple and easy to follow for your new team as possible.
    To do this, you'll want to:
    1. Read the guideline all the way through, carefully
    2. Read the rationale for context, but do not create any questions based on it.
    3. Break the guidelines out into sub guidelines based on the procedure being requested.
    4. For each sub guideline, identify the questions that will comprise the checklists.
    5. Guidelines sometimes highlight when a procedure is particularly useful. These are NOT requirements.Do not include questions in these cases.
    6. Formulate a series of checklists, at least 1 for each procedure
    7. Because these are checklists, you'll want to phrase your questions such that the desired answer is "Yes" or "True".
    If your medical interns can answer "Yes" or "True" to all of the questions in any of your checklists, it means that the procedure is medically necessary, and they should approve it.
    """

def get_step_3_text():
    return """
  Now your job will be to create a flowchart of all of the checklists. But there are a few rules you must follow:
  Rule 1: The first node must be "start" 
  Rule 2: The ONLY leaf node permitted is "Procedure Medically Necessary". (This is because I do not care about paths that lead to denial. They can be omitted) 
  Rule 3: Questions/Nodes may ONLY be connected with the Answer/Arc "Yes". Remember to convert the check list titles themselves into "Yes" questions, like the checklist items. 
  Rule 4: Convert Logical OR condition to parallel flows
  Rule 4a: If you have a series of questions where ANY of them can be True/Yes, then they should be represented as parallel paths, not serial paths.
  So if you have 3 procedures: 
  - Procedure 1
  - Procedure 2
  - Procedure 3 
  The "start" node should first go to nodes in this form:
  - "Is Procedure 1 Requested"
  - "Is Procedure 2 Requested"
  - "Is Procedure 3 Requested"
  Rule 4b: If a checklist items has sub options, and the question asks if any of the following sub-options are true, you should create a separate, parallel flow for all sub options.
  Rule 4c: If a checklist has sub options, and the question asks if the user has ANY of the following sub-options, you should create a separate, parallel flow for all sub options.
  Rule 44: If a checklist has sub options, and the question asks if the user does NOT have ANY of the following sub-options, you should create a serial flow for all sub options.
  Rule 5: Your response should include the mermaid flowchart inside <mermaid></mermaid> tags. 
  Rule 6: Be sure that the labels for all mermaid nodes are enclosed in quotes to avoid syntax errors
  """

# %%
client = anthropic.Anthropic(
    api_key=os.getenv("CLAUDE_KEY")
)

# %%
import json
import hashlib
import diskcache as dc

cache = dc.Cache("data")

def hash_parameters(*args, **kwargs):
    """Create a hash of the function parameters."""
    kwargs.pop("response_format", None)
    params = json.dumps((args, kwargs))
    return hashlib.md5(params.encode()).hexdigest()

def cached(func):
    def wrapper(*args, **kwargs):
        cache_kwargs = kwargs.copy()
        if "client" in cache_kwargs:
            cache_kwargs.pop("client")
        key = f"{func.__name__}:{hash_parameters(*args, **cache_kwargs)}"
        if key in cache:
            return cache[key]
        result = func(*args, **kwargs)
        cache[key] = result
        return result

    return wrapper

# %%
@cached
def get_claude_response(messages):
    response = client.messages.create(
        model="claude-3-5-sonnet-20240620",
        max_tokens=1024,
        messages=messages,
        temperature=0.0,
        top_p=0.95,
    )
    return response

# %%
import backoff
import requests


# Implement backoff logic that will retry the request
@backoff.on_predicate(
    backoff.runtime,  # Exponential backoff
    predicate=lambda r: r.status_code == 429,
    value=lambda r: int(r.headers.get("Retry-After")),
)
@cached
def get_gpt_response_api(prompt, model_name, endpoint, key, temperature):
    headers = {
        # "authorization": f"Bearer {key}",
        "api-key": key,
        "Content-Type": "application/json"
    }

    modified_schema = {
        "type": "object",
        "required": ["results"],
        "additionalProperties": False,
        "properties": {
            "results": {
                "type": "object",
                    "required": ["summary", "discussion", "answers"],
                    "additionalProperties": False,
                    "properties": {
                        "summary": {
                            "type": "string",
                            "description": "Summary of the patient information focusing on aspects that are relevant to the question(s)"
                        },
                        "discussion": {
                            "type": "string",
                            "description": "How does the provided information help or not help to answer the questions?"
                        },
                        "answers": {
                            "type": "array",
                            "items": {
                                "type": "object",
                                "required": ["answer", "supporting evidence"],
                                "additionalProperties": False,
                                "properties": {
                                    "answer": {
                                        "type": "string",
                                        "description": "The correct answer choice among the multiple choices"
                                    },
                                    "supporting evidence": {
                                        "type": "string",
                                        "description": "A direct quote from the patient information that supports the answer if one exists."
                                    }
                                }
                            }
                        }
                    }
                }
            }
        }

    # The data being sent in the request, including the schema and prompt
    data = {
        "model": model_name,
        "messages": prompt,
        "temperature": temperature,
        # "logprobs": True,
        # "top_logprobs": 5,
        # "response_format": {
        #     "type": "json_schema",
        #     "json_schema": {
        #         "name": "QuestionAnswers",
        #         "strict": True,
        #         "schema": modified_schema
        #     }
        # }
    }

    # Send the request
    print(f"ENDPOINT: {endpoint}")
    response = requests.post(endpoint, headers=headers, json=data)
    return response

@cached
def get_gpt_response(messages, model_name, endpoint, key):
    try:
        return openai.ChatCompletion.create(
            api_key=key,
            api_base=endpoint,
            api_version=os.getenv("AZURE_OPENAI_API_VERSION"),
            api_type="azure",
            engine=model_name,
            messages=messages,
            temperature=0.0,
            top_p=0.95,
            frequency_penalty=0,
            presence_penalty=0,
            stop=None,
        )
    except openai.InvalidRequestError:
        return {"choices": [{"message": {"content": "Question 1: The request was deemed invalid and likely violated the content filters."}}]}

# %%
url = "https://guidelines.carelonmedicalbenefitsmanagement.com/imaging-of-the-chest-2024-04-14/"
markdown = "#Other thoracic mass lesions Advanced imaging is considered medically necessary for diagnosis and management of **ANY** of the following findings or conditions: - Mediastinal mass (see separate indication for lymphadenopathy) - Pancoast tumor - Pleural mass - Thymoma - Benign tumors (pediatric only) **IMAGING STUDY** \*\*_ADULT_ \*\* - CT chest - MRI chest for evaluation of mediastinal and hilar masses when CT is insufficient for problem solving or for evaluation of chest wall extension in Pancoast tumor \*\*_PEDIATRIC_ \*\* - CT or MRI chest"
topic = "Other thoracic mass lesions"
def get_mermaid_from_gpt(topic, markdown):
    message = [{"role": "system", "content": get_step_1_text(topic)},
            {"role": "user", "content": markdown}]
    response = get_gpt_response(message, 
                                    model_name="gpt-4o-latest", 
                                    endpoint=os.getenv("AZURE_OPENAI_ENDPOINT_EAST2"), 
                                    key=os.getenv("AZURE_OPENAI_API_KEY_EAST2"), 
                                    # temperature=0.0
                                    )
    message.append({"role": "system",
                    "content": response["choices"][0]["message"]["content"]})
    message.append({"role": "user",
                    "content": get_step_3_text()})
    second_response = get_gpt_response(message,
                                    model_name="gpt-4o-latest",
                                    endpoint=os.getenv("AZURE_OPENAI_ENDPOINT_EAST2"),
                                    key=os.getenv("AZURE_OPENAI_API_KEY_EAST2"))
    return second_response["choices"][0]["message"]["content"]

def get_mermaid_from_claude(topic, markdown):
    message = [{"role": "user", "content": get_step_1_text(topic)},
            {"role": "user", "content": markdown}]
    response = get_claude_response(message)
    message.append({"role": "assistant",
                    "content": response.content[0].text})
    message.append({"role": "user",
                    "content": get_step_3_text()})
    second_response = get_claude_response(message)
    return second_response.content[0].text

import time
start_time = time.time()
get_mermaid_from_claude(topic, markdown)
print(f"Finished in {(time.time()-start_time):.4f} seconds")
# Out:
# <>:2: SyntaxWarning: invalid escape sequence '\*'
# <>:2: SyntaxWarning: invalid escape sequence '\*'
# /tmp/ipykernel_184440/4021527686.py:2: SyntaxWarning: invalid escape sequence '\*'
#   markdown = "#Other thoracic mass lesions Advanced imaging is considered medically necessary for diagnosis and management of **ANY** of the following findings or conditions: - Mediastinal mass (see separate indication for lymphadenopathy) - Pancoast tumor - Pleural mass - Thymoma - Benign tumors (pediatric only) **IMAGING STUDY** \*\*_ADULT_ \*\* - CT chest - MRI chest for evaluation of mediastinal and hilar masses when CT is insufficient for problem solving or for evaluation of chest wall extension in Pancoast tumor \*\*_PEDIATRIC_ \*\* - CT or MRI chest"
# Finished in 5.2881 seconds

# %%
import scorcery
import scorcery.create_local_overrides

override_path = "overrides.db"
if not os.path.isfile(override_path):
    scorcery.create_local_overrides.migrate_postgres_to_sqlite(override_path)

# %%
import scorcery.final_db
from peewee import SqliteDatabase
import scorcery.final_db.guideline_repo
import scorcery.flows
import graph_tools


target_db = SqliteDatabase(override_path)
count = 0
match_count = 0
score_total = 0
target_title = "Penile, Vaginal, and Vulvar Cancers"
for target in scorcery.final_db.guideline_repo.GuidelineRepo.all(target_db):
    count += 1
    response = get_mermaid_from_claude(target.title, target.id)
    try:
        # score = scorcery.flows.score_flows(target.flow, response)
        # print(f"{score:.4f} - {target.title}")
        g1 = graph_tools.EMGraph.from_mermaid(target.flow)
        g2 = graph_tools.EMGraph.from_mermaid(response)
        print(g1.is_similar_to(g2))
        score_total += score
        match_count += 1
        if score < 0.6:
            print("&"*100)
            print(target.flow)
            print("*"*50)
            print(response)
            print("&"*100)
    
    except Exception as e:
        # print("&"*100)
        print(f"Error: {target.title} failed because: {e}")
        # print("*"*50)
        # print(target.flow)
        # print("*"*50)
        # print(response)
        # print("&"*100)
    
    # break

print(count)
print(match_count)
# Out:
# 0.8338 - Head and Neck Cancer
# 0.8032 - Lower extremity pain, not otherwise specified
# 0.8180 - Pulmonary embolism
# 0.7316 - Penile, Vaginal, and Vulvar Cancers
# 0.9505 - Temporomandibular joint dysfunction
# 0.8642 - Weight loss
# 0.7672 - Chest wall mass
# 0.3975 - Pulmonary hypertension
# &&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&
# flowchart TD
#     C["Start"] --> A{"Is this to evaluate\nsuspected pulmonary\nhypertension (including CTEPH)?"}
#     C --> B{"Is this to evaluate disease extent\nafter diagnosis of CTEPH in patients\nbeing considered for surgery?"}
#
#     A --> |Yes| MN["Procedure Medically Necessary"]
#     B --> |Yes| MN
# **************************************************
# Based on the checklists and the rules provided, I've created a flowchart for the pulmonary hypertension advanced imaging guidelines. Here's the mermaid flowchart:
#
# <mermaid>
# graph TD
#     A["Start"] --> B["Is CT chest or CTA chest requested?"]
#     B --> |Yes| C["Is evaluation for suspected pulmonary hypertension needed?"]
#     B --> |Yes| D["Is evaluation of disease extent in diagnosed CTEPH needed?"]
#
#     C --> |Yes| E["Does the suspected pulmonary hypertension include possible CTEPH?"]
#     E --> |Yes| F["Procedure Medically Necessary"]
#
#     D --> |Yes| G["Has the patient been diagnosed with CTEPH?"]
#     G --> |Yes| H["Is the patient being considered for surgery?"]
#     H --> |Yes| I["Is the imaging requested to evaluate the extent of the disease?"]
#     I --> |Yes| F
# </mermaid>
#
# This flowchart represents the two main pathways for considering the advanced imaging procedures (CT chest or CTA chest) as medically necessary for pulmonary hypertension. It follows the rules by starting with a "Start" node, only including "Yes" paths, and ending with the "Procedure Medically Necessary" node. The two main scenarios (evaluation of suspected pulmonary hypertension and evaluation of disease extent in diagnosed CTEPH) are represented as parallel flows from the initial imaging request question.
# &&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&
# 1.0000 - Coronary artery calcium (CAC)
# 0.7888 - Aneurysm, intracranial
# 0.6395 - Avascular necrosis
# 0.8958 - Localized facial pain (including trigeminal neuralgia)
# 0.7089 - Hemoperitoneum
# 0.9011 - Poorly-differentiated neuroendocrine tumor
# 0.7132 - Pancreatic Cancer
# 0.7142 - Tumor/Neoplasm Indeterminate bone lesion
# 0.7682 - Soft Tissue Sarcoma
# 0.7765 - Retroperitoneal conditions
# 0.7339 - Splenic mass, benign
# 0.5853 - Visual Disturbance
# &&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&
# flowchart TD
#     A["Start"] -->B["Is there a central nervous system pathology suggested by ophthalmologic exam?"]
#     B -->C["Procedure Medically Necessary"]
# **************************************************
# Based on the guidelines and the rules provided, I'll create a flowchart for the visual disturbance checklist. Since there's only one procedure (advanced imaging) and one set of criteria, the flowchart will be relatively straightforward.
#
# <mermaid>
# graph TD
#     A["Start"] --> B["Is advanced imaging for visual disturbance requested?"]
#     B -->|Yes| C["Is the patient being evaluated for central nervous system pathology?"]
#     C -->|Yes| D["Has an ophthalmologic exam been performed?"]
#     D -->|Yes| E["Did the ophthalmologic exam suggest the presence of central nervous system pathology?"]
#     E -->|Yes| F["Procedure Medically Necessary"]
# </mermaid>
#
# This flowchart adheres to all the rules specified:
# 1. The first node is "Start".
# 2. The only leaf node is "Procedure Medically Necessary".
# 3. All connections are made with "Yes" answers.
# 4. There are no logical OR conditions in this case, so Rule 4 doesn't apply.
# 5. The mermaid flowchart is enclosed in <mermaid></mermaid> tags.
# 6. All node labels are enclosed in quotes to avoid syntax errors.
#
# The flowchart represents the single path to determine if advanced imaging for visual disturbance is medically necessary, based on the provided guideline.
# &&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&
# 0.7993 - Brachial plexopathy
# 0.8627 - Congenital or developmental vascular anomalies, not otherwise specified
# 0.8586 - Constipation (Pediatric only)
# 0.5951 - Esophageal and Gastroesophageal Junction Cancers
# &&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&
# flowchart TD
#   start["Start"]
#   ct_chest["Is a CT Chest requested?"]
#   ct_abdomen["Is a CT Abdomen requested?"]
#   ct_pelvis["Is a CT Pelvis requested?"]
#   mri_chest["Is a Chest MRI requested?"]
#   mri_abdomen["Is an Abdomen MRI requested?"]
#   is_ct_contra["Is a CT contraindicated or expected to be suboptimal (due to contrast allergy or anticipated contrast nephrotoxicity)."]
#   mri_pelvis["Is a Pelvic MRI requested?"]
#   maybe_pelvic_disease["Is there clinical suspicion of pelvic disease?"]
#   maybe_pelvic_disease_mri["Is there clinical suspicion of pelvic disease?"]
#   is_ct_pelvis_contra["Is a CT contraindicated or expected to be suboptimal (due to contrast allergy or anticipated contrast nephrotoxicity)."]
#   fdg["Is an FDG PET/CT requested?"]
#   fdg_diag["Is imaging needed for a diagnostic workup?"]
#   fdg_diag_q1["Can standard imaging not be performed?"]
#   fdg_diag_q2["Does standard imaging not demonstrate distant (M1) metastatic disease?"]
#   fdg_mgmt["Is imaging needed for management?"]
#   fdg_mgmt_q1["Is the procedure for Radiation planning for preoperative or definitive treatment?"]
#   fdg_mgmt_q2["Is the procedure for Single assessment of response to chemoradiation (as definitive treatment or prior to surgery) when performed at least 5 weeks after completion of therapy?"]
#   fdg_mgmt_q3["Can Standard imaging not be performed"]
#   fdg_mgmt_q4["Is Standard imaging nondiagnostic for recurrent or progressive disease?"]
#   pmc["Procedure Medically Necessary"]
#   start --> mri_chest
#   start --> mri_abdomen
#   start --> mri_pelvis
#   mri_pelvis --> is_ct_pelvis_contra
#   is_ct_pelvis_contra --> maybe_pelvic_disease_mri
#   maybe_pelvic_disease_mri --> pmc
#   start --> ct_chest
#   start --> ct_abdomen
#   start --> ct_pelvis
#   start --> fdg
#   ct_chest --> pmc
#   ct_abdomen --> pmc
#   mri_chest --> is_ct_contra
#   mri_abdomen --> is_ct_contra
#   is_ct_contra --> pmc
#   ct_pelvis --> maybe_pelvic_disease
#   maybe_pelvic_disease --> pmc
#   fdg --> fdg_diag
#   fdg_diag --> fdg_diag_q1
#   fdg_diag --> fdg_diag_q2
#   fdg_diag_q1 --> pmc
#   fdg_diag_q2 --> pmc
#   fdg --> fdg_mgmt
#   fdg_mgmt --> fdg_mgmt_q1
#   fdg_mgmt --> fdg_mgmt_q2
#   fdg_mgmt --> fdg_mgmt_q3
#   fdg_mgmt --> fdg_mgmt_q4
#   fdg_mgmt_q1 --> pmc
#   fdg_mgmt_q2 --> pmc
#   fdg_mgmt_q3 --> pmc
#   fdg_mgmt_q4 --> pmc
# **************************************************
# Here's the flowchart based on the checklists and following the rules you've provided:
#
# <mermaid>
# graph TD
#     A["Start"] --> B["Is CT Chest/Abdomen requested?"]
#     A --> C["Is CT Pelvis requested?"]
#     A --> D["Is FDG-PET/CT requested?"]
#     A --> E["Is MRI requested?"]
#
#     B --> F["Is it for a patient with documented esophageal or gastroesophageal junction cancer?"]
#     F --> G["Is it for diagnostic workup?"]
#     F --> H["Is it for management?"]
#     F --> I["Is it for surveillance within the first 2-3 years after treatment?"]
#
#     C --> J["Is it for a patient with documented esophageal or gastroesophageal junction cancer?"]
#     J --> K["Is there clinical suspicion for pelvic disease?"]
#     K --> L["Is it for diagnostic workup?"]
#     K --> M["Is it for management?"]
#     K --> N["Is it for surveillance?"]
#
#     D --> O["Is it for a patient with documented esophageal or gastroesophageal junction cancer?"]
#     O --> P["Is it for diagnostic workup and standard imaging cannot be performed?"]
#     O --> Q["Is it for diagnostic workup and standard imaging does not demonstrate distant (M1) metastatic disease?"]
#     O --> R["Is it for radiation planning for preoperative or definitive treatment?"]
#     O --> S["Is it for a single assessment of response to chemoradiation at least 5 weeks after completion of therapy?"]
#     O --> T["Is it for management and standard imaging cannot be performed or is nondiagnostic for recurrent or progressive disease?"]
#
#     E --> U["Is it for a patient with documented esophageal or gastroesophageal junction cancer?"]
#     U --> V["Does the patient meet the criteria for CT imaging based on the relevant checklist?"]
#     V --> W["Is CT contraindicated due to contrast allergy?"]
#     V --> X["Is CT expected to be suboptimal due to anticipated contrast nephrotoxicity?"]
#
#     G --> Z["Procedure Medically Necessary"]
#     H --> Z
#     I --> Z
#     L --> Z
#     M --> Z
#     N --> Z
#     P --> Z
#     Q --> Z
#     R --> Z
#     S --> Z
#     T --> Z
#     W --> Z
#     X --> Z
# </mermaid>
# &&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&
# 0.2500 - Inflammatory conditions – not otherwise specified
# &&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&
# graph TD
#     A["Start"] -->B["Procedure Medically Necessary"]
# **************************************************
# Based on the guidelines and the rules provided, I've created a flowchart for the advanced imaging in inflammatory conditions not otherwise specified. Here's the mermaid flowchart:
#
# <mermaid>
# graph TD
#     A["Start"] --> B["Is imaging requested for diagnosis or management of an inflammatory condition not otherwise specified?"]
#     B --> |Yes| C["Is CT orbit, sella, or posterior fossa and outer, middle, or inner ear requested?"]
#     B --> |Yes| D["Is MRI orbit, face, and neck (soft tissue) requested?"]
#     B --> |Yes| E["Is CT paranasal sinuses and maxillofacial area requested?"]
#     B --> |Yes| F["Is CT soft tissue neck requested?"]
#     B --> |Yes| G["Is MRI temporomandibular joint requested?"]
#
#     C --> |Yes| H["Procedure Medically Necessary"]
#     D --> |Yes| H
#     E --> |Yes| H
#     F --> |Yes| H
#
#     G --> |Yes| I["Is the MRI for suspected inflammatory arthritis, including juvenile idiopathic arthritis (JIA)?"]
#     I --> |Yes| J["Have initial radiographs been performed prior to requesting the MRI?"]
#     J --> |Yes| H
# </mermaid>
#
# This flowchart follows all the specified rules:
# 1. The first node is "Start".
# 2. The only leaf node is "Procedure Medically Necessary".
# 3. All connections are made with "Yes" answers.
# 4. Logical OR conditions are represented as parallel flows from the initial question about the type of imaging requested.
# 5. The mermaid flowchart is enclosed in <mermaid></mermaid> tags.
# 6. All node labels are enclosed in quotes to avoid syntax errors.
#
# The flowchart accurately represents the checklists created earlier, with each imaging type having its own path to approval, and the MRI temporomandibular joint having additional criteria that must be met.
# &&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&
# 0.9536 - Sacroiliitis, not otherwise specified
# 0.6561 - Appendicitis
# 0.7874 - Acute aortic syndrome
# 0.8031 - Thyroid Cancer
# 0.5142 - Hydronephrosis
# &&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&
# flowchart TD
#   start["Start"]
#   ct["CT Requested?"]
#   mri["MRI Requested?"]
#   pediatric["Is the patient a child?"]
#   ct_not_performable["Can a CT not be performed?"]
#   ct_not_diagnostic["Is a CT non diagnostic"]
#   pmc["Procedure Medically Necessary"]
#   start --> ct
#   ct --> pmc
#   start --> mri
#   mri --> pediatric
#   mri --> ct_not_performable
#   mri --> ct_not_diagnostic
#   pediatric --> pmc
#   ct_not_performable --> pmc
#   ct_not_diagnostic --> pmc
# **************************************************
# Based on the checklist and the rules provided, I'll create a flowchart for the advanced imaging in hydronephrosis. Since there are two possible procedures (CT and MRI) with slightly different criteria, I'll create parallel paths for each.
#
# <mermaid>
# flowchart TD
#     A["Start"] --> B["Is CT abdomen/pelvis requested?"]
#     A --> C["Is MRI abdomen and pelvis (MR urogram) requested?"]
#
#     B --> D["Has the patient undergone an ultrasound for suspected hydronephrosis?"]
#     C --> E["Has the patient undergone an ultrasound for suspected hydronephrosis?"]
#
#     D --> F["Was the ultrasound nondiagnostic?"]
#     E --> G["Was the ultrasound nondiagnostic?"]
#
#     F --> H["Is advanced imaging being requested for diagnosis or management of hydronephrosis?"]
#     G --> I["Is advanced imaging being requested for diagnosis or management of hydronephrosis?"]
#
#     H --> J["Procedure Medically Necessary"]
#     I --> K["Is the patient pediatric?"]
#     I --> L["Is the patient an adult for whom CT cannot be performed or was nondiagnostic?"]
#
#     K --> J
#     L --> J
# </mermaid>
# &&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&
# 0.9086 - Nontraumatic spinal fractures
# Error: Bladder and Urothelial Cancers failed because: 'IsForWorkupManagementSurveillanceMuscle'
# 0.5009 - Bell’s palsy (peripheral facial nerve palsy)
# &&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&
# graph TD
#     start["Start"]
#     addl_findings["Are there additional neurologic findings suggestive of intracranial pathology?"]
#     pmc["Procedure Medically Necessary"]
#     6wks["Have symptoms persisted beyond 6 weeks?"]
#     no_mri["Is MRI contraindicated?"]
#     ct["Is CT brain being requested?"]
#     mri["Is MRI Brain being requested?"]
#
#     start --> addl_findings
#     start --> 6wks
#     addl_findings --> ct
#     addl_findings --> mri
#     6wks --> ct
#     6wks --> mri
#     mri --> pmc
#     ct --> no_mri
#     no_mri --> pmc
# **************************************************
# Based on the guidelines and the rules provided, I'll create a flowchart for the Bell's palsy imaging criteria. Here's the mermaid flowchart:
#
# <mermaid>
# graph TD
#     A["Start"] --> B["Is advanced imaging for Bell's palsy requested?"]
#     B --> |Yes| C["Are there additional neurologic findings suggestive of intracranial pathology?"]
#     B --> |Yes| D["Have symptoms persisted beyond 6 weeks?"]
#     C --> |Yes| E["Procedure Medically Necessary"]
#     D --> |Yes| F["Are there no additional neurologic findings present?"]
#     F --> |Yes| E
# </mermaid>
#
# This flowchart represents the two scenarios where advanced imaging for Bell's palsy is considered medically necessary. It follows the rules by:
#
# 1. Starting with a "Start" node
# 2. Only having "Procedure Medically Necessary" as the leaf node
# 3. Using only "Yes" connections between nodes
# 4. Representing the OR condition with parallel flows from the initial question
# 5. Using mermaid syntax enclosed in tags
# 6. Enclosing all node labels in quotes
#
# The flowchart shows that if either of the two scenarios (atypical presentation or persistent symptoms) is true, the procedure is considered medically necessary.
# &&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&
# 0.8907 - Intra-cardiac and para-cardiac masses and tumors
# 0.6556 - Chronic lymphocytic leukemia or small lymphocytic lymphoma
# 0.9602 - Sports hernia (athletic pubalgia)
# 0.7826 - Other thoracic mass lesions
# 0.7283 - Ovarian Cancer – All Variants > FDG-PET/CT
# 0.7038 - Bladder or urethral diverticula
# 0.7927 - Non-specific mid-back pain (thoracic)
# 0.8198 - Stenosis or occlusion of the abdominal aorta or branch vessels, not otherwise specified
# 0.7678 - Neck mass (including lymphadenopathy)
# 42
# 41

# %%
print("CLAUDE")
print(score_total)
print(score_total / count)
print(score_total / match_count)
# Out:
# CLAUDE
# 30.982390811691197
# 0.7376759717069332
# 0.7556680685778341

# %%
print("gpt-4o-latest")
print(score_total)
print(score_total / count)
print(score_total / match_count)
# Out:
# gpt-4o-latest
# 30.982390811691197
# 0.7376759717069332
# 0.7556680685778341
