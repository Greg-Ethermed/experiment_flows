# %%
import anthropic
import os
from dotenv import load_dotenv
import openai

load_dotenv(".env")
# Out:
# False

# %%
def get_step_1_text(topic):
    return f"""
    You are an expert medical doctor with a specialty in {topic}. You have specifically been the final arbiter for managing prior authorizations for decades.
    I have a medical guideline from an insurance provider, written in markdown. The guidelines lay out all of the criteria by which a procedure or often multiple procedures might be considered "medically necessary". There are usually multiple paths that will yield this result.
    You will be hiring a team of medical interns to help you perform more prior authorizations accurately. Your task is to make these medical guidelines as simple and easy to follow for your new team as possible.
    To do this, you'll want to:
    1. Read the guideline all the way through, carefully
    2. Read the rationale for context, but do not create any questions based on it.
    3. Break the guidelines out into sub guidelines based on the procedure being requested.
    4. For each sub guideline, identify the questions that will comprise the checklists.
    5. Guidelines sometimes highlight when a procedure is particularly useful. These are NOT requirements.Do not include questions in these cases.
    6. Formulate a series of checklists, at least 1 for each procedure
    7. Make sure that the questions in the checklists are broken down into their most fundamental parts. For example: 'Is this a follow-up of an equivocal post-treatment PET scan, no sooner than 4 weeks after the study?' should be split into 'Is this a follow up of an equivocal post-treatment PET scan?' and 'Was the previous scan conducted at least 4 weeks ago?'.
    8. Because these are checklists, you'll want to phrase your questions such that the desired answer is "Yes" or "True".
    9. Label the questions with an alpha ID, starting with A
    If your medical interns can answer "Yes" or "True" to all of the questions in any of your checklists, it means that the procedure is medically necessary, and they should approve it.
    """

def get_step_3_text():
    return """
  Now your job will be to create a logicial representation of the checklists. But there are a few rules you must follow:
  Rule 1: Reference the checklist items by their alpha ids in the logic statement.
  Rule 2: Ensure that all questions are broken down into their most fundamental parts.
  Rule 3: Avoid duplicating logic where possible.
  Rule 4: Only use the logical operators AND or OR
  Rule 5: Organize the logical statement using parentheses.
  Rule 6: DO NOT use the NOT opperator (or ~). If there is the need for negating a checklist item, an additional item must be added to the list that phrases the question such that the answer is affirmative.
  Rule 7: Return only the logic statement with no additional text or explanation. For example: "(A AND (B OR C OR D) and E)" is a valid response.
  Rule 8: The logic statement must be all one line and all connected by logical opperators.
  Rule 9: Your full response should be a json. The first key should be "logic_statement" with your logic statement as the value. The second key should be "questions". This value should be a dictionary where they keys are the alpha ids and they values are the questions. 
  """

# %%
client = anthropic.Anthropic(
    api_key=os.getenv("CLAUDE_KEY")
)

# %%
import json
import hashlib
import diskcache as dc

cache = dc.Cache("data")

def hash_parameters(*args, **kwargs):
    """Create a hash of the function parameters."""
    kwargs.pop("response_format", None)
    params = json.dumps((args, kwargs))
    return hashlib.md5(params.encode()).hexdigest()

def cached(func):
    def wrapper(*args, **kwargs):
        cache_kwargs = kwargs.copy()
        if "client" in cache_kwargs:
            cache_kwargs.pop("client")
        key = f"{func.__name__}:{hash_parameters(*args, **cache_kwargs)}"
        if key in cache:
            return cache[key]
        result = func(*args, **kwargs)
        cache[key] = result
        return result

    return wrapper

# %%
@cached
def get_claude_response(messages):
    response = client.messages.create(
        model="claude-3-5-sonnet-20240620",
        max_tokens=1024,
        messages=messages,
        temperature=0.0,
        top_p=0.95,
    )
    return response

# %%
import backoff
import requests


# Implement backoff logic that will retry the request
@backoff.on_predicate(
    backoff.runtime,  # Exponential backoff
    predicate=lambda r: r.status_code == 429,
    value=lambda r: int(r.headers.get("Retry-After")),
)
@cached
def get_gpt_response_api(prompt, model_name, endpoint, key, temperature):
    headers = {
        # "authorization": f"Bearer {key}",
        "api-key": key,
        "Content-Type": "application/json"
    }

    modified_schema = {
        "type": "object",
        "required": ["results"],
        "additionalProperties": False,
        "properties": {
            "results": {
                "type": "object",
                    "required": ["summary", "discussion", "answers"],
                    "additionalProperties": False,
                    "properties": {
                        "summary": {
                            "type": "string",
                            "description": "Summary of the patient information focusing on aspects that are relevant to the question(s)"
                        },
                        "discussion": {
                            "type": "string",
                            "description": "How does the provided information help or not help to answer the questions?"
                        },
                        "answers": {
                            "type": "array",
                            "items": {
                                "type": "object",
                                "required": ["answer", "supporting evidence"],
                                "additionalProperties": False,
                                "properties": {
                                    "answer": {
                                        "type": "string",
                                        "description": "The correct answer choice among the multiple choices"
                                    },
                                    "supporting evidence": {
                                        "type": "string",
                                        "description": "A direct quote from the patient information that supports the answer if one exists."
                                    }
                                }
                            }
                        }
                    }
                }
            }
        }

    # The data being sent in the request, including the schema and prompt
    data = {
        "model": model_name,
        "messages": prompt,
        "temperature": temperature,
        # "logprobs": True,
        # "top_logprobs": 5,
        # "response_format": {
        #     "type": "json_schema",
        #     "json_schema": {
        #         "name": "QuestionAnswers",
        #         "strict": True,
        #         "schema": modified_schema
        #     }
        # }
    }

    # Send the request
    print(f"ENDPOINT: {endpoint}")
    response = requests.post(endpoint, headers=headers, json=data)
    return response

@cached
def get_gpt_response(messages, model_name, endpoint, key):
    try:
        return openai.ChatCompletion.create(
            api_key=key,
            api_base=endpoint,
            api_version=os.getenv("AZURE_OPENAI_API_VERSION"),
            api_type="azure",
            engine=model_name,
            messages=messages,
            temperature=0.0,
            top_p=0.95,
            frequency_penalty=0,
            presence_penalty=0,
            stop=None,
        )
    except openai.InvalidRequestError:
        return {"choices": [{"message": {"content": "Question 1: The request was deemed invalid and likely violated the content filters."}}]}

# %%
url = "https://guidelines.carelonmedicalbenefitsmanagement.com/imaging-of-the-chest-2024-04-14/"
markdown = "#Other thoracic mass lesions Advanced imaging is considered medically necessary for diagnosis and management of **ANY** of the following findings or conditions: - Mediastinal mass (see separate indication for lymphadenopathy) - Pancoast tumor - Pleural mass - Thymoma - Benign tumors (pediatric only) **IMAGING STUDY** \*\*_ADULT_ \*\* - CT chest - MRI chest for evaluation of mediastinal and hilar masses when CT is insufficient for problem solving or for evaluation of chest wall extension in Pancoast tumor \*\*_PEDIATRIC_ \*\* - CT or MRI chest"
topic = "Other thoracic mass lesions"
def get_mermaid_from_gpt(topic, markdown):
    message = [{"role": "system", "content": get_step_1_text(topic)},
            {"role": "user", "content": markdown}]
    response = get_gpt_response(message, 
                                    model_name="gpt-4o-latest", 
                                    endpoint=os.getenv("AZURE_OPENAI_ENDPOINT_EAST2"), 
                                    key=os.getenv("AZURE_OPENAI_API_KEY_EAST2"), 
                                    # temperature=0.0
                                    )
    message.append({"role": "system",
                    "content": response["choices"][0]["message"]["content"]})
    message.append({"role": "user",
                    "content": get_step_3_text()})
    second_response = get_gpt_response(message,
                                    model_name="gpt-4o-latest",
                                    endpoint=os.getenv("AZURE_OPENAI_ENDPOINT_EAST2"),
                                    key=os.getenv("AZURE_OPENAI_API_KEY_EAST2"))
    return second_response["choices"][0]["message"]["content"]

def get_mermaid_from_claude(topic, markdown):
    message = [{"role": "user", "content": get_step_1_text(topic)},
            {"role": "user", "content": markdown}]
    response = get_claude_response(message)
    message.append({"role": "assistant",
                    "content": response.content[0].text})
    message.append({"role": "user",
                    "content": get_step_3_text()})
    second_response = get_claude_response(message)
    return second_response.content[0].text

import time
start_time = time.time()
get_mermaid_from_claude(topic, markdown)
print(f"Finished in {(time.time()-start_time):.4f} seconds")
# Out:
# Finished in 0.0006 seconds
# <>:2: SyntaxWarning: invalid escape sequence '\*'
# <>:2: SyntaxWarning: invalid escape sequence '\*'
# /tmp/ipykernel_129996/4021527686.py:2: SyntaxWarning: invalid escape sequence '\*'
#   markdown = "#Other thoracic mass lesions Advanced imaging is considered medically necessary for diagnosis and management of **ANY** of the following findings or conditions: - Mediastinal mass (see separate indication for lymphadenopathy) - Pancoast tumor - Pleural mass - Thymoma - Benign tumors (pediatric only) **IMAGING STUDY** \*\*_ADULT_ \*\* - CT chest - MRI chest for evaluation of mediastinal and hilar masses when CT is insufficient for problem solving or for evaluation of chest wall extension in Pancoast tumor \*\*_PEDIATRIC_ \*\* - CT or MRI chest"

# %%
import scorcery
import scorcery.create_local_overrides

override_path = "overrides.db"
if not os.path.isfile(override_path):
    scorcery.create_local_overrides.migrate_postgres_to_sqlite(override_path)

# %%
import scorcery.final_db
from peewee import SqliteDatabase
import scorcery.final_db.guideline_repo
import scorcery.flows
import graph_tools


target_db = SqliteDatabase(override_path)
count = 0
match_count = 0
score_total = 0
target_title = "Penile, Vaginal, and Vulvar Cancers"
for target in scorcery.final_db.guideline_repo.GuidelineRepo.all(target_db):
    count += 1
    response = get_mermaid_from_claude(target.title, target.id)
    response = json.loads(response)
    # print(json.dumps(response, indent=4))
    # print("*"*100)
    try:
        # score = scorcery.flows.score_flows(target.flow, response)
        # print(f"{score:.4f} - {target.title}")
        print(target.title)
        g1 = graph_tools.graph.EMGraph.from_mermaid(target.flow)
        g2 = graph_tools.graph.EMGraph.from_logic(response["logic_statement"], response["questions"])
        g2.as_logic_graph()
        similarity = g1.is_similar_to(g2)
        print(f"NODES: {similarity["node overlap"]}")
        if similarity["node overlap"] > 1.0:
            for pair in similarity["shared nodes"]:
                print(pair)
            print([concept.question for concept in g1.compendium.concepts])
            print([concept.question for concept in g2.compendium.concepts])
        print(f"LEN SHARED CONCEPTS: {len(similarity["shared nodes"])}")
        print(f"G1: {len(g1.compendium.concepts)}")
        print(f"G2: {len(g2.compendium.concepts)}")
        score = (similarity["node overlap"] + similarity["outcome overlap"]) / 2.0
        print(f"SCORE: {score}")
        score_total += score
        match_count += 1
        # if score < 0.6:
        #     print("&"*100)
        #     print(target.flow)
        #     print("*"*50)
        #     print(g2.get_mermaid_text())
        #     print("&"*100)
    
    except Exception as e:
        print("&"*100)
        print(f"Error: {target.title} failed because: {e}")
        print("*"*50)
        print(target.flow)
        print("*"*50)
        print(response)
        print("&"*100)
    
    # break

print(count)
print(match_count)
# Out:
# Head and Neck Cancer
# NODES: 0.43478260869565216
# LEN SHARED CONCEPTS: 5
# G1: 21
# G2: 6
# SCORE: 0.4692663043478261
# Lower extremity pain, not otherwise specified
# NODES: 0.6666666666666666
# LEN SHARED CONCEPTS: 3
# G1: 6
# G2: 7
# SCORE: 0.7746708333333333
# Pulmonary embolism
# NODES: 0.9090909090909091
# LEN SHARED CONCEPTS: 10
# G1: 15
# G2: 11
# SCORE: 0.8266454545454545
# Penile, Vaginal, and Vulvar Cancers
# NODES: 0.8148148148148148
# LEN SHARED CONCEPTS: 11
# G1: 19
# G2: 12
# SCORE: 0.6617324074074074
# Temporomandibular joint dysfunction
# NODES: 1.2
# ('Does the patient have mechanical symptoms (such as locking, popping, or clicking) of the temporomandibular joint?', 'Does the patient have mechanical symptoms (such as locking, popping, or clicking) of the temporomandibular joint?')
# ('Is surgical intervention being considered for the patient?', 'Is surgical intervention being considered for the temporomandibular joint dysfunction?')
# ('Has the patient had a short-term trial of soft diet and proper chewing techniques?', 'Did the conservative treatment include a short-term trial of soft diet and proper chewing techniques?')
# ('Has the patient used an oral appliance (such as a bite block)?', 'Did the conservative treatment include an oral appliance (such as a bite block)?')
# ('Has the patient used nonsteroidal anti-inflammatory drugs or acetaminophen?', 'Did the conservative treatment include nonsteroidal anti-inflammatory drugs or acetaminophen?')
# ('Has the patient completed a six-week course of conservative treatment with no improvement in symptoms?', 'Have these symptoms failed to improve with a six-week course of conservative treatment?')
# LEN SHARED CONCEPTS: 6
# G1: 8
# G2: 6
# SCORE: 1.0925
# Weight loss
# NODES: 1.0769230769230769
# ('Are there abnormal findings suggestive of malignancy on history, physical exam, imaging, or laboratory evaluation?', 'Are there abnormal findings suggestive of malignancy on history, physical exam, imaging, or laboratory evaluation?')
# ('Has there been unintentional weight loss exceeding 5% of body weight within a 12-month interval?', 'Has the patient experienced unintentional weight loss exceeding 5% of body weight within a 12-month interval?')
# ('Has there been persistence following a negative comprehensive clinical evaluation after a period of observation?', 'Has there been a period of observation after the comprehensive clinical evaluation?')
# ('Did the comprehensive clinical exam include age-appropriate cancer screening?', 'Has age-appropriate cancer screening been performed?')
# ('Did the comprehensive clinical exam include a history and physical examination?', 'Has a history and physical examination been performed?')
# ('Did the comprehensive clinical exam include initial laboratory evaluation?', 'Has initial laboratory evaluation been performed?')
# ('Did the comprehensive clinical exam include chest radiography?', 'Has chest radiography been performed?')
# LEN SHARED CONCEPTS: 7
# G1: 9
# G2: 8
# SCORE: 0.9715490384615384
# Chest wall mass
# NODES: 0.8333333333333334
# LEN SHARED CONCEPTS: 5
# G1: 8
# G2: 8
# SCORE: 0.7566666666666667
# Pulmonary hypertension
# NODES: 0.4
# LEN SHARED CONCEPTS: 1
# G1: 4
# G2: 5
# SCORE: 0.5160625000000001
# Coronary artery calcium (CAC)
# NODES: 0.9142857142857143
# LEN SHARED CONCEPTS: 16
# G1: 21
# G2: 18
# SCORE: 0.9571428571428571
# Aneurysm, intracranial
# NODES: 0.7428571428571429
# LEN SHARED CONCEPTS: 13
# G1: 22
# G2: 17
# SCORE: 0.5979410714285714
# Avascular necrosis
# NODES: 0.75
# LEN SHARED CONCEPTS: 3
# G1: 7
# G2: 5
# SCORE: 0.7587375000000001
# Localized facial pain (including trigeminal neuralgia)
# NODES: 1.2
# ('Is the facial pain localized?', 'Is the facial pain localized to a specific area?')
# ('Is the facial pain persistent?', 'Has the facial pain been persistent?')
# ('Is the facial pain unexplained?', 'Is the cause of the facial pain unexplained after initial evaluation?')
# LEN SHARED CONCEPTS: 3
# G1: 5
# G2: 4
# SCORE: 1.06605
# Hemoperitoneum
# NODES: 1.3333333333333333
# ('Is the evaluation for diagnosis?', 'Is the imaging being requested for the diagnosis of hemoperitoneum?')
# ('Is the evaluation for management?', 'Is the imaging being requested for the management of hemoperitoneum?')
# LEN SHARED CONCEPTS: 2
# G1: 4
# G2: 3
# SCORE: 1.1666666666666665
# Poorly-differentiated neuroendocrine tumor
# NODES: 0.9473684210526315
# LEN SHARED CONCEPTS: 9
# G1: 12
# G2: 11
# SCORE: 0.6314342105263158
# Pancreatic Cancer
# NODES: 0.5384615384615384
# LEN SHARED CONCEPTS: 7
# G1: 21
# G2: 9
# SCORE: 0.4827682692307692
# Tumor/Neoplasm Indeterminate bone lesion
# NODES: 1.0
# LEN SHARED CONCEPTS: 2
# G1: 4
# G2: 4
# SCORE: 0.9358375
# Soft Tissue Sarcoma
# NODES: 0.88
# LEN SHARED CONCEPTS: 11
# G1: 16
# G2: 13
# SCORE: 0.7755624999999999
# Retroperitoneal conditions
# NODES: 1.1428571428571428
# ('Does the patient have Fibrosis?', 'Does the patient have retroperitoneal fibrosis?')
# ('Does the patient have Inflammation?', 'Does the patient have retroperitoneal inflammation?')
# ('Does the patient have Bleeding?', 'Does the patient have retroperitoneal bleeding?')
# ('Does the patient have a Mass?', 'Does the patient have a retroperitoneal mass?')
# ('Is the request for CT abdomen and/or pelvis?', 'Is the patient an adult and is CT abdomen and/or pelvis being requested?')
# ('Is the patient a pediatric patient?', 'Is the patient pediatric and is MRI abdomen and/or pelvis being requested?')
# ('Can CT be performed and is it diagnostic?', 'Is the patient an adult and is MRI abdomen and/or pelvis being requested because CT cannot be performed or was nondiagnostic?')
# ('Is the request for MRI Abdomen and/or Pelvis?', 'Is the imaging being requested for diagnosis or management of a retroperitoneal condition?')
# LEN SHARED CONCEPTS: 8
# G1: 10
# G2: 8
# SCORE: 1.0339285714285715
# Splenic mass, benign
# NODES: 0.8
# LEN SHARED CONCEPTS: 2
# G1: 7
# G2: 2
# SCORE: 0.59675
# Visual Disturbance
# NODES: 1.0
# LEN SHARED CONCEPTS: 1
# G1: 3
# G2: 3
# SCORE: 0.8671125
# Brachial plexopathy
# NODES: 0.5714285714285714
# LEN SHARED CONCEPTS: 2
# G1: 6
# G2: 5
# SCORE: 0.6690267857142858
# Congenital or developmental vascular anomalies, not otherwise specified
# NODES: 0.2222222222222222
# LEN SHARED CONCEPTS: 1
# G1: 10
# G2: 3
# SCORE: 0.4936611111111111
# Constipation (Pediatric only)
# NODES: 1.125
# ('Is there failure of medical management?', 'Is there failure of medical management?')
# ('Is there failure to thrive?', 'Is there failure to thrive?')
# ('Is there suspicion of tight empty rectum?', 'Is there suspicion of tight empty rectum following barium enema or anal manometry?')
# ('Is there suspicion of anal stenosis?', 'Is there suspicion of anal stenosis following barium enema or anal manometry?')
# ('Is there fever?', 'Is fever present?')
# ('Is there vomiting?', 'Is vomiting present?')
# ('Is there suspicion of impaction in patients <1 year old?', 'Is there suspicion of impaction in a patient younger than 1 year of age following barium enema or anal manometry?')
# ('Have symptoms persisted for 2+ weeks after nondiagnostic radiographs?', 'Has the patient had symptoms persisting for 2 or more weeks?')
# ('Has barium enema or anal manometry been performed?', 'Have radiographs been performed and found to be nondiagnostic?')
# LEN SHARED CONCEPTS: 9
# G1: 11
# G2: 9
# SCORE: 0.9650000000000001
# Esophageal and Gastroesophageal Junction Cancers
# NODES: 0.7027027027027027
# LEN SHARED CONCEPTS: 13
# G1: 19
# G2: 22
# SCORE: 0.6897513513513513
# Inflammatory conditions – not otherwise specified
# NODES: 0.0
# LEN SHARED CONCEPTS: 0
# G1: 2
# G2: 4
# SCORE: 0.2487875
# Sacroiliitis, not otherwise specified
# NODES: 1.0
# LEN SHARED CONCEPTS: 3
# G1: 7
# G2: 3
# SCORE: 0.9612625
# Appendicitis
# NODES: 0.5454545454545454
# LEN SHARED CONCEPTS: 6
# G1: 16
# G2: 10
# SCORE: 0.5747522727272727
# Acute aortic syndrome
# NODES: 0.8571428571428571
# LEN SHARED CONCEPTS: 3
# G1: 6
# G2: 5
# SCORE: 0.8353339285714285
# Thyroid Cancer
# NODES: 0.8444444444444444
# LEN SHARED CONCEPTS: 19
# G1: 23
# G2: 26
# SCORE: 0.6547222222222222
# Hydronephrosis
# NODES: 0.4444444444444444
# LEN SHARED CONCEPTS: 2
# G1: 7
# G2: 6
# SCORE: 0.3667097222222222
# Nontraumatic spinal fractures
# NODES: 1.2
# ('Is imaging needed to direct intervention?', 'Is the imaging needed to direct intervention?')
# ('Are radiographs nondiagnostic?', 'Are the radiographs nondiagnostic?')
# ('Is pain persistent after two-week conservative management?', 'Has the patient experienced persistent pain after a two-week course of conservative management?')
# ('Is it a diagnosis of compression fracture?', 'Is the imaging being requested for the diagnosis of a compression fracture?')
# ('Is it management of fragility fracture?', 'Is the imaging being requested for the management of a fragility fracture?')
# ('Does pain worsen during conservative management?', "Has the patient's pain worsened during conservative management?")
# LEN SHARED CONCEPTS: 6
# G1: 8
# G2: 6
# SCORE: 0.915
# Bladder and Urothelial Cancers
# NODES: 0.8275862068965517
# LEN SHARED CONCEPTS: 12
# G1: 17
# G2: 16
# SCORE: 0.7408931034482759
# Bell’s palsy (peripheral facial nerve palsy)
# NODES: 0.8571428571428571
# LEN SHARED CONCEPTS: 3
# G1: 7
# G2: 4
# SCORE: 0.7874589285714286
# Intra-cardiac and para-cardiac masses and tumors
# NODES: 0.8888888888888888
# LEN SHARED CONCEPTS: 8
# G1: 14
# G2: 8
# SCORE: 0.7344444444444445
# Chronic lymphocytic leukemia or small lymphocytic lymphoma
# NODES: 0.7058823529411765
# LEN SHARED CONCEPTS: 6
# G1: 14
# G2: 7
# SCORE: 0.6117411764705882
# Sports hernia (athletic pubalgia)
# NODES: 0.9230769230769231
# LEN SHARED CONCEPTS: 6
# G1: 9
# G2: 8
# SCORE: 0.9566134615384616
# Other thoracic mass lesions
# NODES: 1.0
# LEN SHARED CONCEPTS: 11
# G1: 14
# G2: 12
# SCORE: 0.859425
# Ovarian Cancer – All Variants > FDG-PET/CT
# NODES: 0.7619047619047619
# LEN SHARED CONCEPTS: 8
# G1: 16
# G2: 9
# SCORE: 0.8118273809523809
# Bladder or urethral diverticula
# NODES: 2.0
# ('Is the request for diagnosis?', 'Is the MRI pelvis being requested for the diagnosis of bladder or urethral diverticula?')
# ('Is the request for management?', 'Is the MRI pelvis being requested for the management of bladder or urethral diverticula?')
# LEN SHARED CONCEPTS: 2
# G1: 4
# G2: 2
# SCORE: 1.225
# Non-specific mid-back pain (thoracic)
# NODES: 0.7058823529411765
# LEN SHARED CONCEPTS: 6
# G1: 15
# G2: 6
# SCORE: 0.7818161764705882
# Stenosis or occlusion of the abdominal aorta or branch vessels, not otherwise specified
# NODES: 1.0
# LEN SHARED CONCEPTS: 10
# G1: 14
# G2: 10
# SCORE: 0.685
# Neck mass (including lymphadenopathy)
# NODES: 0.8260869565217391
# LEN SHARED CONCEPTS: 19
# G1: 31
# G2: 19
# SCORE: 0.5635934782608696
# 42
# 42

# %%
print("CLAUDE")
print(score_total)
print(score_total / count)
print(score_total / match_count)
# Out:
# CLAUDE
# 32.08108289526291
# 0.7638353070300693
# 0.7638353070300693

# %%
print("gpt-4o-latest")
print(score_total)
print(score_total / count)
print(score_total / match_count)
# Out:
# gpt-4o-latest
# 32.08108289526291
# 0.7638353070300693
# 0.7638353070300693
