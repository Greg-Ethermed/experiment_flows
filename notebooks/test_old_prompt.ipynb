# %%
import anthropic
import os
from dotenv import load_dotenv
import openai

load_dotenv(".env")
# Out:
# False

# %%
def guideline_to_flowchart_prompt(
    reformatted_guidelines: str,
) -> dict[str, str]:
    """
    Convert reformated guidelines to flowchart prompt.

    Args:
        reformatted_guidelines (str): Reformatted guidelines.

    Returns:
        Dict[str, str]: OpenAI messages with reformatted guidelines
    """

    # Payload for the request
    payload = {
        "messages": [
            {
                "role": "user",
                "content": [
                    {
                        "type": "text",
                        "text": "Create a flowchart in flowchart TD syntax from given medical \
                                guidelines. You need to convert each step of the guideline to question \
                                so that it could be answered 'Yes' or 'No' \
                                Pay close attention to details, since we do not want to omit anything. \
                                Best, go over guidelines and reason step by step. \
                                Make sure everything ends with either: \
                                'Procedure Medically Necessary' or 'Procedure not Medically Necessary' \
                                Also, make sure you encapsulate all nodes into square brackets: '[' \
                                and labels into double quotes. \
                                Please output generated flowchart only without any additional comments. \
                                Guidelines text: \n\n ``` "
                        + reformatted_guidelines
                        + " ```",
                    },
                ],
            },
        ],
    }

    return payload["messages"]

def extract_necessary_requirements_assertion_prompt(parsed_guideline: str) -> str:
    """
    Extracts the necessary requirements assertion prompt from the parsed guideline.

    Args:
        parsed_guideline (str): The parsed guideline.

    Returns:
        str: The necessary requirements assertion prompt.

    """
    extract_requirements_prompt = [
        {
            "role": "system",
            "content": """Please create a flowchart diagramming whether the stated procedure is \
                medically necessary given the following information. Ensure that there are no parenthesis \
                in the labels, and omit subgraphs and any nodes other than questions (diamonds in \
                flowchart parlance) that could be answered true or false by reading through a medical \
                pre-auth request. If the input is empty, return None.""",
        },
        {
            "role": "user",
            "content": """#### Craniocervical junction abnormalities\n\n_Includes atlantoaxial and \
                occipital instability as well as basilar\ninvagination_\n\nAdvanced imaging of the \
                spine is considered medically necessary for diagnosis\nand management following \
                nondiagnostic radiographs in persons with **ANY** of\nthe following high-risk \
                conditions:\n\n-\n\nDown syndrome\n\n-\n\nGrisel syndrome\n\n-\n\nSkeletal \
                dysplasia\n\n-\n\nRheumatoid arthritis\n\n**IMAGING STUDY**\n\n-\n\nCT cervical \
                spine\n\n-\n\nMRI cervical spine\n\n##### Rationale\n\nRheumatoid arthritis is a \
                systemic inflammatory disease that affects the\ncervical spine in up to 80% of \
                cases resulting in craniocervical instability,\nmost commonly from atlantoaxial \
                subluxation. MRI is the most sensitive exam to\nestablish the diagnosis,1 which \
                carries an increased risk of mortality and\nmorbidity in rheumatoid arthritis \
                patients,2 and lifetime radiological follow\nup may be required.\n""",
        },
        {
            "role": "assistant",
            "content": """flowchart TD
                A["Does the patient have craniocervical junction abnormalities?"] \
                    -->|Yes| B["Have nondiagnostic radiographs been performed?"]
                A -->|No| End1["Procedure not medically necessary"]
                B -->|Yes| C["Does the patient have any of the high-risk conditions?"]
                B -->|No| End1
                C -->|Yes| D["Down syndrome?"]
                C -->|No| End1
                D -->|Yes| E["Advanced imaging CT or MRI is medically necessary"]
                D -->|No| F["Grisel syndrome?"]
                F -->|Yes| E
                F -->|No| G["Skeletal dysplasia?"]
                G -->|Yes| E
                G -->|No| H["Rheumatoid arthritis?"]
                H -->|Yes| E
                H -->|No| End1
                E --> I["CT cervical spine"]
                E --> J["MRI cervical spine"]""",
        },
        {"role": "user", "content": parsed_guideline},
    ]

    return extract_requirements_prompt

# %%
client = anthropic.Anthropic(
    api_key=os.getenv("CLAUDE_KEY")
)

# %%
import json
import hashlib
import diskcache as dc

cache = dc.Cache("data")

def hash_parameters(*args, **kwargs):
    """Create a hash of the function parameters."""
    kwargs.pop("response_format", None)
    params = json.dumps((args, kwargs))
    return hashlib.md5(params.encode()).hexdigest()

def cached(func):
    def wrapper(*args, **kwargs):
        cache_kwargs = kwargs.copy()
        if "client" in cache_kwargs:
            cache_kwargs.pop("client")
        key = f"{func.__name__}:{hash_parameters(*args, **cache_kwargs)}"
        if key in cache:
            return cache[key]
        result = func(*args, **kwargs)
        cache[key] = result
        return result

    return wrapper

# %%
@cached
def get_claude_response(messages):
    response = client.messages.create(
        model="claude-3-5-sonnet-20240620",
        max_tokens=1024,
        messages=messages,
        temperature=0.0,
        top_p=0.95,
    )
    return response

# %%
import backoff
import requests


# Implement backoff logic that will retry the request
@backoff.on_predicate(
    backoff.runtime,  # Exponential backoff
    predicate=lambda r: r.status_code == 429,
    value=lambda r: int(r.headers.get("Retry-After")),
)
@cached
def get_gpt_response_api(prompt, model_name, endpoint, key, temperature):
    headers = {
        # "authorization": f"Bearer {key}",
        "api-key": key,
        "Content-Type": "application/json"
    }

    modified_schema = {
        "type": "object",
        "required": ["results"],
        "additionalProperties": False,
        "properties": {
            "results": {
                "type": "object",
                    "required": ["summary", "discussion", "answers"],
                    "additionalProperties": False,
                    "properties": {
                        "summary": {
                            "type": "string",
                            "description": "Summary of the patient information focusing on aspects that are relevant to the question(s)"
                        },
                        "discussion": {
                            "type": "string",
                            "description": "How does the provided information help or not help to answer the questions?"
                        },
                        "answers": {
                            "type": "array",
                            "items": {
                                "type": "object",
                                "required": ["answer", "supporting evidence"],
                                "additionalProperties": False,
                                "properties": {
                                    "answer": {
                                        "type": "string",
                                        "description": "The correct answer choice among the multiple choices"
                                    },
                                    "supporting evidence": {
                                        "type": "string",
                                        "description": "A direct quote from the patient information that supports the answer if one exists."
                                    }
                                }
                            }
                        }
                    }
                }
            }
        }

    # The data being sent in the request, including the schema and prompt
    data = {
        "model": model_name,
        "messages": prompt,
        "temperature": temperature,
        # "logprobs": True,
        # "top_logprobs": 5,
        # "response_format": {
        #     "type": "json_schema",
        #     "json_schema": {
        #         "name": "QuestionAnswers",
        #         "strict": True,
        #         "schema": modified_schema
        #     }
        # }
    }

    # Send the request
    print(f"ENDPOINT: {endpoint}")
    response = requests.post(endpoint, headers=headers, json=data)
    return response

@cached
def get_gpt_response(messages, model_name, endpoint, key):
    try:
        return openai.ChatCompletion.create(
            api_key=key,
            api_base=endpoint,
            api_version=os.getenv("AZURE_OPENAI_API_VERSION"),
            api_type="azure",
            engine=model_name,
            messages=messages,
            temperature=0.0,
            top_p=0.95,
            frequency_penalty=0,
            presence_penalty=0,
            stop=None,
        )
    except openai.InvalidRequestError:
        return {"choices": [{"message": {"content": "Question 1: The request was deemed invalid and likely violated the content filters."}}]}

# %%
url = "https://guidelines.carelonmedicalbenefitsmanagement.com/imaging-of-the-chest-2024-04-14/"
markdown = "#Other thoracic mass lesions Advanced imaging is considered medically necessary for diagnosis and management of **ANY** of the following findings or conditions: - Mediastinal mass (see separate indication for lymphadenopathy) - Pancoast tumor - Pleural mass - Thymoma - Benign tumors (pediatric only) **IMAGING STUDY** \*\*_ADULT_ \*\* - CT chest - MRI chest for evaluation of mediastinal and hilar masses when CT is insufficient for problem solving or for evaluation of chest wall extension in Pancoast tumor \*\*_PEDIATRIC_ \*\* - CT or MRI chest"
topic = "Other thoracic mass lesions"
def get_mermaid_from_gpt(topic, markdown):
    message = guideline_to_flowchart_prompt(markdown)
    response = get_gpt_response(message, 
                                    model_name="gpt-4o-latest", 
                                    endpoint=os.getenv("AZURE_OPENAI_ENDPOINT_EAST2"), 
                                    key=os.getenv("AZURE_OPENAI_API_KEY_EAST2"), 
                                    # temperature=0.0
                                    )
    return response["choices"][0]["message"]["content"]

def get_mermaid_from_claude(topic, markdown):
    message = guideline_to_flowchart_prompt(markdown)
    response = get_claude_response(message)
    return response.content[0].text

import time
start_time = time.time()
get_mermaid_from_claude(topic, markdown)
print(f"Finished in {(time.time()-start_time):.4f} seconds")
# Out:
# Finished in 0.0008 seconds
# <>:2: SyntaxWarning: invalid escape sequence '\*'
# <>:2: SyntaxWarning: invalid escape sequence '\*'
# /tmp/ipykernel_29873/2641030083.py:2: SyntaxWarning: invalid escape sequence '\*'
#   markdown = "#Other thoracic mass lesions Advanced imaging is considered medically necessary for diagnosis and management of **ANY** of the following findings or conditions: - Mediastinal mass (see separate indication for lymphadenopathy) - Pancoast tumor - Pleural mass - Thymoma - Benign tumors (pediatric only) **IMAGING STUDY** \*\*_ADULT_ \*\* - CT chest - MRI chest for evaluation of mediastinal and hilar masses when CT is insufficient for problem solving or for evaluation of chest wall extension in Pancoast tumor \*\*_PEDIATRIC_ \*\* - CT or MRI chest"

# %%
import scorcery
import scorcery.create_local_overrides

override_path = "overrides.db"
if not os.path.isfile(override_path):
    scorcery.create_local_overrides.migrate_postgres_to_sqlite(override_path)

# %%
import scorcery.final_db
from peewee import SqliteDatabase
import scorcery.final_db.guideline_repo
import scorcery.flows
import graph_tools


target_db = SqliteDatabase(override_path)
count = 0
match_count = 0
score_total = 0
target_title = "Penile, Vaginal, and Vulvar Cancers"
for target in scorcery.final_db.guideline_repo.GuidelineRepo.all(target_db):
    count += 1
    response = get_mermaid_from_gpt(target.title, target.id)
    try:
        experiment_flow = graph_tools.graph.EMGraph.from_mermaid(response)
        experiment_flow.as_logic_graph()
        score = scorcery.flows.score_flows(target.flow, experiment_flow.get_mermaid_text())
        print(f"{score:.4f} - {target.title}")
        score_total += score
        match_count += 1
        if score < 0.6:
            print("&"*100)
            print(target.flow)
            print("*"*50)
            print(response)
            print("&"*100)
    
    except Exception as e:
        print("&"*100)
        print(f"Error: {target.title} failed because: {e}")
        print("*"*50)
        print(target.flow)
        print("*"*50)
        print(response)
        print("&"*100)
    
    # break

print(count)
print(match_count)
# Out:
# 0.5535 - Head and Neck Cancer
# &&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&
# graph TD
#     A["Start"] --> B{"Is CT Primary Site and Neck Requested?"}
#     A --> C{"Is CT Chest / CT Abdomen and Pelvis Requested?"}
#     A --> D{"Is MRI Primary Site and Neck Requested?"}
#     A --> E{"Is FDG-PET/CT Requested?"}
#
#     B --> F{"Is there documented head and neck cancer?"}
#     F --> G{"Is this for initial diagnostic workup?"}
#     F --> H{"Is this to assess response to neoadjuvant treatment or after concurrent chemoradiotherapy?"}
#     F --> I{"Is this for surveillance imaging?"}
#     G --> J["Procedure Medically Necessary"]
#     H --> J
#     I --> J
#
#     C --> K{"Is there documented head and neck cancer?"}
#     K --> L{"Is this for initial diagnostic workup?"}
#     K --> M{"Is this part of the management strategy?"}
#     K --> N{"Is this for surveillance imaging?"}
#     L --> J
#     M --> J
#     N --> J
#
#     D --> O{"Is there documented head and neck cancer?"}
#     O --> P{"Is this for initial diagnostic workup?"}
#     O --> Q{"Is this to assess response to neoadjuvant treatment or after concurrent chemoradiotherapy?"}
#     O --> R{"Is this for surveillance imaging?"}
#     O --> S{"Is CT contraindicated or expected to be suboptimal?"}
#     P --> S
#     Q --> S
#     R --> S
#     S --> J
#
#     E --> T{"Is there documented head and neck cancer?"}
#     T --> U{"Is this for initial diagnostic workup?"}
#     T --> V{"Is this for management?"}
#     U --> W{"Is this for evaluation of locoregionally advanced cancers?"}
#     U --> X{"Is this following biopsy suggestive of a head and neck primary tumor when CT or MRI has not detected a primary site?"}
#     U --> Y{"Is this NOT for initial evaluation of lip or salivary gland cancers?"}
#     W --> Y
#     X --> Y
#     Y --> J
#     V --> Z{"Is this for radiation planning for preoperative or definitive treatment only?"}
#     V --> AA{"Is this for treatment response evaluation, no sooner than 12 weeks after completion of therapy?"}
#     V --> AB{"Is standard imaging nondiagnostic for recurrent or progressive disease?"}
#     V --> AC{"Is this for follow up of an equivocal post-treatment PET scan, no sooner than 4 weeks after the study?"}
#     V --> AD{"Is this NOT for adjuvant radiation therapy planning when all known disease has been removed?"}
#     Z --> AD
#     AA --> AD
#     AB --> AD
#     AC --> AD
#     AD --> J
# **************************************************
# ```flowchart
# flowchart TD
#     A["Is there a documented case of head and neck cancer?"] -->|Yes| B["Is advanced imaging for diagnostic workup needed?"]
#     A -->|No| Z["Procedure not Medically Necessary"]
#     B -->|Yes| C["Is CT of the primary site and neck indicated?"]
#     B -->|No| Z
#     C -->|Yes| D["Is CT chest, abdomen, and pelvis indicated?"]
#     C -->|No| E["Is MRI of the primary site and neck indicated?"]
#     D -->|Yes| E
#     D -->|No| E
#     E -->|Yes| F["Is FDG-PET/CT indicated for locoregionally advanced cancers or unknown primary tumor?"]
#     E -->|No| G["Is advanced imaging for management needed?"]
#     F -->|Yes| G
#     F -->|No| G
#     G -->|Yes| H["Is CT of the primary site and neck indicated for assessing treatment response?"]
#     G -->|No| Z
#     H -->|Yes| I["Is CT chest, abdomen, and pelvis indicated for management?"]
#     H -->|No| J["Is MRI of the primary site and neck indicated for assessing treatment response?"]
#     I -->|Yes| J
#     I -->|No| J
#     J -->|Yes| K["Is FDG-PET/CT indicated for radiation planning or treatment response evaluation?"]
#     J -->|No| L["Is advanced imaging for surveillance needed?"]
#     K -->|Yes| L
#     K -->|No| L
#     L -->|Yes| M["Is CT of the primary site and neck indicated for surveillance?"]
#     L -->|No| Z
#     M -->|Yes| N["Is CT chest, abdomen, and pelvis indicated for surveillance in patients with smoking history?"]
#     M -->|No| O["Is MRI of the primary site and neck indicated for surveillance?"]
#     N -->|Yes| O
#     N -->|No| O
#     O -->|Yes| P["Is FDG-PET/CT not indicated for surveillance?"]
#     O -->|No| Z
#     P -->|Yes| Q["Procedure Medically Necessary"]
#     P -->|No| Z
# ```
# &&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&
# 0.7129 - Lower extremity pain, not otherwise specified
# 0.6872 - Pulmonary embolism
# &&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&
# Error: Penile, Vaginal, and Vulvar Cancers failed because: Graph type 'Undetermined' cannot be converted.
# **************************************************
# flowchart TD
#     A["Start"]
#     A --> B["Is CT chest, CT abdomen and pelvis requested?"]
#     A --> C["Is MRI pelvis requested?"]
#     A --> D["Is FDG-PET/CT requested?"]
#
#
#     B --> F["Is this for diagnostic workup?"]
#     B --> G["Is this for management?"]
#     B --> H["Is this for surveillance?"]
#     H --> I["Does the patient have penile cancer?"]
#
#     F --> M["Procedure Medically Necessary"]
#     G --> M
#     I --> M
#
#     A --> E["Is MRI Chest requested?"]
#     A --> J["Is MRI Abdomen requested?"]
#
#     E --> K["Is CT contraindicated or expected to be suboptimal (due to contrast allergey or anticipated contrast nephrotoxicity)?"]
#     J --> K
#     K --> F
#     K --> G
#     K --> H
#     C --> N["Is there documented vaginal or vulvar cancer?"]
#     N --> O["Is this for diagnostic workup?"]
#     N --> P["Is this for management?"]
#
#     O --> M
#     P --> M
#
#     D --> U["Is this for diagnostic workup?"]
#     D --> V["Is this for management?"]
#
#     U --> W["Standard imaging cannot be performed or is nondiagnostic for metastatic disease"]
#     U --> X1["Does the patient have penile cancer?"]
#     X1 --> X2["Are pelvic lymph nodes enlarged on CT or MRI?"]
#     X2 --> Y["Is needle biopsy not technically feasible?"]
#
#     V --> Z["Is radiation planning needed for preoperative or definitive treatment?"]
#     V --> AA["Standard imaging cannot be performed or is nondiagnostic for recurrent or progressive disease"]
#     V --> AB["Is this to restage local recurrence when pelvic exenteration sugery is planned?"]
#
#     W --> M
#     Y --> M
#     Z --> M
#     AA --> M
#     AB --> M
# **************************************************
# ```flowchart
# flowchart TD
#     A["Is there a documented case of vaginal, vulvar, or penile cancer?"] -->|Yes| B["Is the imaging for diagnostic workup, management, or surveillance?"]
#     A -->|No| Z["Procedure not Medically Necessary"]
#
#     B -->|Diagnostic Workup| C["Is CT chest, abdomen, and pelvis indicated?"]
#     B -->|Management| F["Is CT chest, abdomen, and pelvis indicated?"]
#     B -->|Surveillance| I["Is CT chest, abdomen, and pelvis indicated for penile cancer?"]
#
#     C -->|Yes| D["Is the cancer penile with T1b or higher or palpable inguinal LN, or vulvar with T2 or higher?"]
#     C -->|No| E["Is MRI pelvis indicated for vaginal or vulvar cancer?"]
#
#     D -->|Yes| Y["Procedure Medically Necessary"]
#     D -->|No| E
#
#     E -->|Yes| Y
#     E -->|No| G["Is FDG-PET/CT indicated because standard imaging cannot be performed or is nondiagnostic for metastatic disease?"]
#
#     F -->|Yes| G
#     F -->|No| H["Is MRI pelvis indicated for vaginal or vulvar cancer?"]
#
#     G -->|Yes| Y
#     G -->|No| H
#
#     H -->|Yes| Y
#     H -->|No| J["Is FDG-PET/CT indicated for radiation planning, nondiagnostic standard imaging for recurrent disease, or restaging of local recurrence?"]
#
#     I -->|Yes| Y
#     I -->|No| K["Is MRI pelvis indicated for vaginal or vulvar cancer?"]
#
#     J -->|Yes| Y
#     J -->|No| L["Is MRI necessary due to CT contraindication or suboptimality?"]
#
#     K -->|Yes| Y
#     K -->|No| M["Is FDG-PET/CT indicated for penile cancer with enlarged pelvic lymph nodes and needle biopsy not feasible?"]
#
#     L -->|Yes| Y
#     L -->|No| Z
#
#     M -->|Yes| Y
#     M -->|No| Z
# ```
# &&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&
# 0.8009 - Temporomandibular joint dysfunction
# &&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&
# Error: Weight loss failed because: 'flowchart'
# **************************************************
# flowchart TD
#     Z["Start"]
#     A["Has there been unintentional weight loss exceeding 5% of body weight within a 12-month interval?"]
#     B["Has there been persistence following a negative comprehensive clinical evaluation after a period of observation?"]
#     C["Did the comprehensive clinical exam include a history and physical examination?"]
#     D["Did the comprehensive clinical exam include age-appropriate cancer screening?"]
#     E["Did the comprehensive clinical exam include chest radiography?"]
#     F["Did the comprehensive clinical exam include initial laboratory evaluation?"]
#     G["Are there abnormal findings suggestive of malignancy on history, physical exam, imaging, or laboratory evaluation?"]
#     AA["Procedure Medically Necessary"]
#     Z-->A
#     A-->B
#     B-->C
#     C-->D
#     D-->E
#     E-->F
#     A-->G
#     F-->AA
#     G-->AA
# **************************************************
# ```flowchart
# flowchart TD
#     A["Has there been unintentional weight loss exceeding 5% of body weight within a 12-month interval?"]
#     A -- "No" --> B["Procedure not Medically Necessary"]
#     A -- "Yes" --> C["Has there been a negative comprehensive clinical evaluation after a period of observation?"]
#     C -- "Yes" --> E["Procedure Medically Necessary"]
#     C -- "No" --> D["Are there abnormal findings suggestive of malignancy on history, physical exam, imaging, or laboratory evaluation?"]
#     D -- "Yes" --> E["Procedure Medically Necessary"]
#     D -- "No" --> B["Procedure not Medically Necessary"]
# ```
# &&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&
# 0.6458 - Chest wall mass
# 0.8273 - Pulmonary hypertension
# &&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&
# Error: Coronary artery calcium (CAC) failed because: Graph type 'Undetermined' cannot be converted.
# **************************************************
# graph TD
#     A["Start"] --> B["Is CAC testing requested?"]
#     B -->|Yes| C["Is patient between 40 and 75 years of age?"]
#     C -->|Yes| D["Does patient have no known atheromatous vascular disease?"]
#     D -->|Yes| E["Is patient non-diabetic?"]
#     E -->|Yes| F["Is LDL cholesterol between 70 and 190 mg/dL?"]
#     F -->|Yes| G["Is 10-year ASCVD risk between 5% and 20%?"]
#     G -->|Yes| H["No family history of premature ASCVD?"]
#     H -->|Yes| I["No persistently elevated LDL (≥160 mg/dL)?"]
#     I -->|Yes| J["No persistently elevated triglycerides (>175 mg/dL)?"]
#     J -->|Yes| K["No metabolic syndrome?"]
#     K -->|Yes| L["No chronic kidney disease?"]
#     L -->|Yes| M["No chronic inflammatory condition?"]
#     M -->|Yes| N["No history of menopause before age 40?"]
#     N -->|Yes| O["No history of preeclampsia?"]
#     O -->|Yes| P["Not of high-risk race/ethnicity?"]
#     P -->|Yes| Q["No elevated high-sensitivity CRP, if measured?"]
#     Q -->|Yes| R["No elevated lipoprotein(a), if measured?"]
#     R -->|Yes| S["No elevated apolipoprotein B, if measured?"]
#     S -->|Yes| T["No ankle-brachial index <0.9, if measured?"]
#     T -->|Yes| U["Procedure Medically Necessary"]
#
# **************************************************
# ```flowchart
# flowchart TD
#     A["Is there any known atheromatous vascular disease?"] -->|Yes| B["Procedure not Medically Necessary"]
#     A -->|No| C["Is the patient diabetic?"]
#     C -->|Yes| B
#     C -->|No| D["Is the patient's age ≥ 40 years and ≤ 75 years?"]
#     D -->|No| B
#     D -->|Yes| E["Is the LDL cholesterol ≥ 70 mg/dL and ≤ 190 mg/dL?"]
#     E -->|No| B
#     E -->|Yes| F["Is the 10-year risk using ASCVD Pooled Cohort Equations ≥ 5% and ≤ 20%?"]
#     F -->|No| B
#     F -->|Yes| G["Does the patient have any of the following conditions?"]
#     G -->|Yes| B
#     G -->|No| H["Procedure Medically Necessary"]
#     subgraph G_conditions ["Conditions"]
#         G1["Family history of premature atherosclerotic cardiovascular disease"]
#         G2["Persistently elevated LDL (≥ 160 mg/dL)"]
#         G3["Persistently elevated triglyceride (> 175mg/dL)"]
#         G4["Metabolic syndrome"]
#         G5["Chronic kidney disease (eGFR 15-59 mL/min/1.73 m²)"]
#         G6["Chronic inflammatory condition"]
#         G7["History of menopause before age 40 years"]
#         G8["History of preeclampsia"]
#         G9["High risk race/ethnicity (e.g., South Asian ancestry)"]
#         G10["Elevated high-sensitivity C-reactive protein (≥ 2.0 mg/L)"]
#         G11["Elevated lipoprotein(a) (> 50mg/dL)"]
#         G12["Apolipoprotein B > 130mg/dL"]
#         G13["Ankle-brachial index less than 0.9"]
#         G --> G1
#         G --> G2
#         G --> G3
#         G --> G4
#         G --> G5
#         G --> G6
#         G --> G7
#         G --> G8
#         G --> G9
#         G --> G10
#         G --> G11
#         G --> G12
#         G --> G13
#     end
# ```
# &&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&
# &&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&
# Error: Aneurysm, intracranial failed because: Graph type 'Undetermined' cannot be converted.
# **************************************************
# graph TD
#     A["Start"] --> B["Is screening for intracranial aneurysm requested?"]
#     A --> C["Is diagnosis of clinically suspected intracranial aneurysm requested?"]
#     A --> D["Is management of known intracranial aneurysm requested?"]
#     A --> E["Is surveillance of known intracranial aneurysm requested?"]
#
#     B --> F["Does the patient have two or more first-degree relatives with intracranial aneurysm or subarachnoid hemorrhage?"]
#     B --> G["Does the patient have a condition associated with an increased risk of intracranial aneurysm?"]
#     B --> H["Does the patient have known fibromuscular dysplasia?"]
#
#     C --> I["Are there CT or MRI findings suspicious for aneurysm?"]
#     C --> J["Does the patient have neurologic signs or symptoms suggestive of intracranial aneurysm?"]
#
#     J --> K["Does the patient have at least one first-degree relative with intracranial aneurysm or subarachnoid hemorrhage?"]
#     J --> L["Does the patient have a condition associated with an increased risk of intracranial aneurysm?"]
#     J --> M["Does the patient have known fibromuscular dysplasia?"]
#     J --> N["Does the patient have cranial nerve deficits?"]
#     J --> O["Does the patient have focal neurologic deficits unexplained by CT or MRI?"]
#     J --> P["Does the patient have sudden onset worst headache of life ('thunderclap')?"]
#     J --> Q["Does the patient have headache brought on by and occurring in association with exertion or Valsalva?"]
#     J --> R["Does the patient have persistent headache that meets Brain Imaging guidelines for headache and remains undifferentiated/unexplained by MRI?"]
#
#     D --> S["Is there a need for evaluation due to new or worsening neurologic symptoms?"]
#     D --> T["Is there a need for preoperative evaluation?"]
#     D --> U["Is there a need for initial postoperative evaluation?"]
#
#     E --> V["Is this the initial evaluation at 6 to 12 months following diagnosis?"]
#     E --> W["Has it been approximately one year since the last evaluation?"]
#
#     F --> X["Procedure Medically Necessary"]
#     G --> X
#     H --> X
#     I --> X
#     K --> X
#     L --> X
#     M --> X
#     N --> X
#     O --> X
#     P --> X
#     Q --> X
#     R --> X
#     S --> X
#     T --> X
#     U --> X
#     V --> X
#     W --> X
# **************************************************
# ```flowchart
# flowchart TD
#     A["Is the patient in a high-risk group for screening?"]
#     A1["Does the patient have two or more first-degree relatives with intracranial aneurysm or subarachnoid hemorrhage?"]
#     A2["Does the patient have a condition associated with an increased risk of intracranial aneurysm (e.g., autosomal dominant polycystic kidney disease, Ehlers-Danlos syndrome type IV)?"]
#     A3["Does the patient have known fibromuscular dysplasia?"]
#     B["Is there a clinically suspected intracranial aneurysm?"]
#     B1["Are there CT or MRI findings suspicious for aneurysm?"]
#     B2["Are there neurologic signs or symptoms suggestive of intracranial aneurysm?"]
#     B2a["Does the patient have at least one first-degree relative with intracranial aneurysm or subarachnoid hemorrhage?"]
#     B2b["Does the patient have a condition associated with an increased risk of intracranial aneurysm (e.g., autosomal dominant polycystic kidney disease, Ehlers-Danlos syndrome type IV)?"]
#     B2c["Does the patient have known fibromuscular dysplasia?"]
#     B2d["Are there cranial nerve deficits?"]
#     B2e["Are there focal neurologic deficits unexplained by CT or MRI?"]
#     B2f["Is there a headache with specific features?"]
#     B2f1["Is it a sudden onset worst headache of life ('thunderclap')?"]
#     B2f2["Is it brought on by and occurring in association with exertion or Valsalva?"]
#     B2f3["Is it a persistent headache that meets Brain Imaging guidelines for headache and remains undifferentiated/unexplained by MRI?"]
#     C["Is there a known intracranial aneurysm requiring management?"]
#     C1["Is there a need for evaluation of aneurysm progression or recurrence based on new or worsening neurologic symptoms?"]
#     C2["Is there a need for preoperative evaluation?"]
#     C3["Is there a need for initial postoperative evaluation?"]
#     D["Is surveillance required?"]
#     D1["Is it the initial evaluation at 6 to 12 months following diagnosis?"]
#     D2["Is it an annual evaluation?"]
#     E["Procedure Medically Necessary"]
#     F["Procedure not Medically Necessary"]
#
#     A -->|Yes| E
#     A -->|No| B
#     A1 -->|Yes| E
#     A1 -->|No| A2
#     A2 -->|Yes| E
#     A2 -->|No| A3
#     A3 -->|Yes| E
#     A3 -->|No| B
#     B -->|Yes| E
#     B -->|No| C
#     B1 -->|Yes| E
#     B1 -->|No| B2
#     B2 -->|Yes| E
#     B2 -->|No| C
#     B2a -->|Yes| E
#     B2a -->|No| B2b
#     B2b -->|Yes| E
#     B2b -->|No| B2c
#     B2c -->|Yes| E
#     B2c -->|No| B2d
#     B2d -->|Yes| E
#     B2d -->|No| B2e
#     B2e -->|Yes| E
#     B2e -->|No| B2f
#     B2f -->|Yes| E
#     B2f -->|No| C
#     B2f1 -->|Yes| E
#     B2f1 -->|No| B2f2
#     B2f2 -->|Yes| E
#     B2f2 -->|No| B2f3
#     B2f3 -->|Yes| E
#     B2f3 -->|No| C
#     C -->|Yes| E
#     C -->|No| D
#     C1 -->|Yes| E
#     C1 -->|No| C2
#     C2 -->|Yes| E
#     C2 -->|No| C3
#     C3 -->|Yes| E
#     C3 -->|No| D
#     D -->|Yes| E
#     D -->|No| F
#     D1 -->|Yes| E
#     D1 -->|No| D2
#     D2 -->|Yes| E
#     D2 -->|No| F
# ```
# &&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&
# 0.5152 - Avascular necrosis
# &&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&
# graph TD
#     start["Start"]
#     rg_nondiagnostic["Are radiographs nondiagnostic?"]
#     ct["Was a CT requested?"]
#     mri["Was an MRI requested?"]
#     mri_not_performable["Can an MRI not be performed?"]
#     mri_not_diag["Was an MRI non-diagnostic?"]
#     pmc["Procedure Medically Necessary"]
#     start --> rg_nondiagnostic
#     rg_nondiagnostic --> ct
#     rg_nondiagnostic --> mri
#     ct --> mri_not_performable
#     ct --> mri_not_diag
#     mri --> pmc
#     mri_not_performable --> pmc
#     mri_not_diag --> pmc
# **************************************************
# ```flowchart TD
# A["Have nondiagnostic radiographs been performed?"] -->|Yes| B["Is the patient high-risk (sickle cell disease, steroid use, alcoholism, chemoradiation, or metabolic bone disease)?"]
# A -->|No| C["Procedure not Medically Necessary"]
#
# B -->|Yes| D["Are radiographs normal or inconclusive?"]
# B -->|No| E["Procedure not Medically Necessary"]
#
# D -->|Yes| F["Can MRI be performed?"]
# D -->|No| G["Procedure not Medically Necessary"]
#
# F -->|Yes| H["Is MRI without IV contrast needed for additional information?"]
# F -->|No| I["Is CT needed because MRI cannot be performed or is nondiagnostic?"]
#
# H -->|Yes| J["Procedure Medically Necessary"]
# H -->|No| K["Procedure not Medically Necessary"]
#
# I -->|Yes| L["Procedure Medically Necessary"]
# I -->|No| M["Procedure not Medically Necessary"]
# ```
# &&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&
# 0.8260 - Localized facial pain (including trigeminal neuralgia)
# 0.2774 - Hemoperitoneum
# &&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&
# graph TD
#     A["Start"] -->|True| C{"Is the evaluation for diagnosis?"}
#     A -->|True| D{"Is the evaluation for management?"}
#     C -->|True| F["Procedure Medically Necessary"]
#     D -->|True| F
# **************************************************
# ```flowchart
# flowchart TD
#     A["Is there a suspicion of hemoperitoneum?"] -->|Yes| B["Is advanced imaging available?"]
#     A -->|No| C["Procedure not Medically Necessary"]
#     B -->|Yes| D["Is CT abdomen and/or pelvis indicated?"]
#     B -->|No| C
#     D -->|Yes| E["Procedure Medically Necessary"]
#     D -->|No| C
# ```
# &&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&
# &&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&
# Error: Poorly-differentiated neuroendocrine tumor failed because: Graph type 'Undetermined' cannot be converted.
# **************************************************
#
# graph TD
#     A["Start"] --> B["Is CT chest, CT abdomen and pelvis requested?"]
#     A --> C["Is MRI abdomen, MRI pelvis requested?"]
#     A --> D["Is FDG-PET/CT requested?"]
#
#     B --> E["Is the patient diagnosed with a poorly-differentiated neuroendocrine tumor (excluding lung)?"]
#     E --> F["Is this for initial staging, treatment response assessment, or surveillance?"]
#     F --> G["Procedure Medically Necessary"]
#
#     C --> H["Is the patient diagnosed with a poorly-differentiated neuroendocrine tumor (excluding lung)?"]
#     H --> I["Is this for initial staging, treatment response assessment, or surveillance?"]
#     I --> G
#
#     D --> J["Is the patient diagnosed with a poorly-differentiated neuroendocrine tumor (excluding lung)?"]
#     J --> K["Is this for initial staging?"]
#     J --> L["Is this for treatment response assessment?"]
#
#     K --> M["Can standard imaging not be performed?"]
#     K --> N["Is standard imaging nondiagnostic for metastatic disease?"]
#     M --> G
#     N --> G
#
#     L --> O["Was PET used for initial staging?"]
#     O --> G
#
# **************************************************
# ```flowchart TD
# A["Is the neuroendocrine tumor poorly differentiated?"] -->|Yes| B["Is the tumor located in the lung?"]
# A -->|No| Z["Procedure not Medically Necessary"]
#
# B -->|Yes| C["Refer to Small Cell Lung Cancer section"]
# B -->|No| D["Is CT chest, abdomen, and pelvis indicated?"]
#
# D -->|Yes| E["Procedure Medically Necessary"]
# D -->|No| F["Is MRI abdomen and pelvis indicated?"]
#
# F -->|Yes| E
# F -->|No| G["Is FDG-PET/CT indicated due to non-diagnostic standard imaging for metastatic disease?"]
#
# G -->|Yes| E
# G -->|No| H["Is FDG-PET/CT indicated to assess treatment response when PET was used for initial staging?"]
#
# H -->|Yes| E
# H -->|No| I["Is SSR imaging indicated for initial staging of well-differentiated neuroendocrine tumors?"]
#
# I -->|Yes| E
# I -->|No| J["Is imaging needed to assess disease response to therapy with the same modality used initially?"]
#
# J -->|Yes| E
# J -->|No| K["Is somatostatin analog receptor imaging needed prior to PRRT?"]
#
# K -->|Yes| E
# K -->|No| L["Is routine surveillance imaging needed for recurrent disease risk?"]
#
# L -->|Yes| E
# L -->|No| Z
# ```
# &&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&
# 0.4088 - Pancreatic Cancer
# &&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&
# graph TD
#     START["Start"]
#     CT_CHEST["Is CT chest requested?"]
#     CT_ABDOMEN["Is CT abdomen requested?"]
#     CT_PELVIS["Is CT pelvis requested?"]
#     MRI["Is MRI pelvis requested?"]
#     FDG["Is an FDG-PET/CT requested?"]
#     DIAG_MRI["Is this procedure diagnostic?"]
#     CT_CONTRA["Is a CT contraindicated?"]
#     CT_SUBOPT["Is a CT expected to be suboptimal?"]
#     CT_LIVER["Are there CT-indeterminate liver lesions?"]
#     RESECTABILITY["Is there a need to establish resectability in borderline cases?"]
#     DIAG_FDG["Is this procedure diagnostic?"]
#     DIAG_FDG_Q1["Has dedicated high-quality pancreatic imaging been performed?"]
#     DIAG_FDG_Q2["Is extra-pancreatic disease absent?"]
#     DIAG_FDG_Q3["Is CA 19-9 >100 U/ml?"]
#     DIAG_FDG_Q4["Is primary tumor >2cm?"]
#     DIAG_FDG_Q5["Are regional nodes enlarged?"]
#     DIAG_FDG_Q6["Is tumor borderline resectable?"]
#
#
#     MGMT_FDG["Is this procedure for management?"]
#     MGMT_FDG_Q1["Is this for radiation planning without distant metastasis?"]
#     MGMT_FDG_Q2["Is standard imaging nondiagnostic for recurrent/progressive disease?"]
#
#     PMC["Procedure Medically Necessary"]
#
#     START --> CT_CHEST
#     START --> CT_ABDOMEN
#     START --> CT_PELVIS
#     START --> MRI
#     START --> FDG
#
#     CT_CHEST --> PMC
#     CT_ABDOMEN --> PMC
#     CT_PELVIS --> PMC
#
#     MRI --> DIAG_MRI
#     DIAG_MRI --> CT_CONTRA
#     DIAG_MRI --> CT_SUBOPT
#     DIAG_MRI --> CT_LIVER
#     DIAG_MRI --> RESECTABILITY
#     CT_CONTRA --> PMC
#     CT_SUBOPT --> PMC
#     CT_LIVER --> PMC
#     RESECTABILITY  --> PMC
#
#     FDG --> DIAG_FDG
#     DIAG_FDG --> DIAG_FDG_Q1
#     DIAG_FDG_Q1 --> DIAG_FDG_Q2
#     DIAG_FDG_Q2 --> DIAG_FDG_Q3
#     DIAG_FDG_Q2 --> DIAG_FDG_Q4
#     DIAG_FDG_Q2 --> DIAG_FDG_Q5
#     DIAG_FDG_Q2 --> DIAG_FDG_Q6
#
#     DIAG_FDG_Q3 --> PMC
#     DIAG_FDG_Q4 --> PMC
#     DIAG_FDG_Q5 --> PMC
#     DIAG_FDG_Q6 --> PMC
#
#     FDG --> MGMT_FDG
#     MGMT_FDG --> MGMT_FDG_Q1
#     MGMT_FDG --> MGMT_FDG_Q2
#     MGMT_FDG_Q1 --> PMC
#     MGMT_FDG_Q2 --> PMC
# **************************************************
# ```flowchart
# TD
#     A["Is there documented pancreatic cancer?"]
#     A -->|Yes| B["Is CT chest indicated?"]
#     A -->|No| Z["Procedure not Medically Necessary"]
#     B -->|Yes| C["Is CT abdomen and pelvis indicated?"]
#     B -->|No| Z
#     C -->|Yes| D["Is MRI abdomen indicated due to CT contraindication or suboptimal results, CT-indeterminate liver lesions, or need to establish resectability?"]
#     C -->|No| Z
#     D -->|Yes| E["Has dedicated, high-quality imaging of the pancreas been performed?"]
#     D -->|No| Z
#     E -->|Yes| F["Is extra-pancreatic disease clearly identified?"]
#     E -->|No| Z
#     F -->|No| G["Are any high-risk features present (Cancer antigen 19-9 > 100 U/ml, Primary tumor > 2 cm, Enlarged regional nodes, Tumor borderline resectable)?"]
#     F -->|Yes| Z
#     G -->|Yes| H["Is FDG-PET/CT indicated for radiation planning or when standard imaging is nondiagnostic?"]
#     G -->|No| Z
#     H -->|Yes| I["Procedure Medically Necessary"]
#     H -->|No| Z
# ```
# &&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&
# 0.8627 - Tumor/Neoplasm Indeterminate bone lesion
# 0.4225 - Soft Tissue Sarcoma
# &&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&
# graph TD
#     A["Start"]
#     D["Is the imaging CT or MRI of the primary site?"]
#     E["Is the imaging CT of the chest?"]
#     F["Is the imaging CT of the abdomen and pelvis?"]
#     G["Is the imaging MRI of the spine?"]
#     H["Is the imaging FDG-PET/CT?"]
#     I["Is it for diagnostic workup?"]
#     I2["Is it for diagnostic workup?"]
#     J["Is it for evaluation of suspected/known spinal metastases?"]
#     L["Is it for management?"]
#     L2["Is it for management?"]
#     M["Is standard imaging non-performable or nondiagnostic for metastatic disease?"]
#     N["Does standard imaging suggest a resectable solitary metastasis?"]
#     O["Is it a baseline study prior to neoadjuvant chemotherapy?"]
#     P["Is it for initial staging of rhabdomyosarcoma?"]
#     Q["Is it following completion of neoadjuvant chemotherapy?"]
#     R["Is standard imaging non-performable or nondiagnostic for recurrent/progressive disease?"]
#     Z["Procedure Medically Necessary"]
#     A-->D
#     D-->Z
#     A-->E
#     E-->Z
#     A-->F
#     F-->Z
#     A-->G
#     G-->I
#     I-->Z
#     G-->L
#     L-->J
#     J-->Z
#     A-->H
#     H-->I2
#     H-->L2
#     I2-->M
#     M-->Z
#     I2-->N
#     N-->Z
#     I2-->O
#     O-->Z
#     I2-->P
#     P-->Z
#     L2-->Q
#     Q-->Z
#     L2-->R
#     R-->Z
# **************************************************
# ```flowchart
# flowchart TD
#     A["Is there a documented sarcoma of bone, cartilage, connective tissue, or other soft tissue?"] -->|Yes| B["Is the sarcoma located in the head/neck, extremity/body wall, retroperitoneal or intra-abdominal sites, or is it a desmoid tumor?"]
#     A -->|No| Z["Procedure not Medically Necessary"]
#
#     B -->|Yes| C["Is CT or MRI of the primary site indicated?"]
#     B -->|No| Z
#
#     C -->|Yes| D["Is CT chest indicated?"]
#     C -->|No| Z
#
#     D -->|Yes| E["Is CT abdomen and pelvis indicated?"]
#     D -->|No| Z
#
#     E -->|Yes| F["Is MRI spine indicated?"]
#     E -->|No| Z
#
#     F -->|Yes| G["Is FDG-PET/CT indicated in any of the following scenarios: 1. Standard imaging cannot be performed or is nondiagnostic for metastatic disease 2. Standard imaging suggests a resectable solitary metastasis 3. Baseline study prior to neoadjuvant chemotherapy 4. Initial staging for rhabdomyosarcoma?"]
#     F -->|No| Z
#
#     G -->|Yes| H["Is FDG-PET/CT indicated following completion of neoadjuvant chemotherapy or when standard imaging cannot be performed or is nondiagnostic for recurrent or progressive disease?"]
#     G -->|No| Z
#
#     H -->|Yes| I["Procedure Medically Necessary"]
#     H -->|No| Z
# ```
# &&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&
# 0.6165 - Retroperitoneal conditions
# 0.6032 - Splenic mass, benign
# 0.5404 - Visual Disturbance
# &&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&
# flowchart TD
#     A["Start"] -->B["Is there a central nervous system pathology suggested by ophthalmologic exam?"]
#     B -->C["Procedure Medically Necessary"]
# **************************************************
# ```flowchart
# TD
#     A["Is there a visual disturbance?"] -->|No| B["Procedure not Medically Necessary"]
#     A -->|Yes| C["Was a central nervous system pathology suggested by the ophthalmologic exam?"]
#     C -->|No| B
#     C -->|Yes| D["Is advanced imaging being considered?"]
#     D -->|No| B
#     D -->|Yes| E["Is MRI brain preferred?"]
#     E -->|Yes| F["Procedure Medically Necessary"]
#     E -->|No| G["Is CT brain being considered?"]
#     G -->|No| B
#     G -->|Yes| F
# ```
# &&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&
# 0.7301 - Brachial plexopathy
# 0.6349 - Congenital or developmental vascular anomalies, not otherwise specified
# 0.7638 - Constipation (Pediatric only)
# &&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&
# Error: Esophageal and Gastroesophageal Junction Cancers failed because: Graph type 'Undetermined' cannot be converted.
# **************************************************
# flowchart TD
#   start["Start"]
#   ct_chest["Is a CT Chest requested?"]
#   ct_abdomen["Is a CT Abdomen requested?"]
#   ct_pelvis["Is a CT Pelvis requested?"]
#   mri_chest["Is a Chest MRI requested?"]
#   mri_abdomen["Is an Abdomen MRI requested?"]
#   is_ct_contra["Is a CT contraindicated or expected to be suboptimal (due to contrast allergy or anticipated contrast nephrotoxicity)."]
#   mri_pelvis["Is a Pelvic MRI requested?"]
#   maybe_pelvic_disease["Is there clinical suspicion of pelvic disease?"]
#   maybe_pelvic_disease_mri["Is there clinical suspicion of pelvic disease?"]
#   is_ct_pelvis_contra["Is a CT contraindicated or expected to be suboptimal (due to contrast allergy or anticipated contrast nephrotoxicity)."]
#   fdg["Is an FDG PET/CT requested?"]
#   fdg_diag["Is imaging needed for a diagnostic workup?"]
#   fdg_diag_q1["Can standard imaging not be performed?"]
#   fdg_diag_q2["Does standard imaging not demonstrate distant (M1) metastatic disease?"]
#   fdg_mgmt["Is imaging needed for management?"]
#   fdg_mgmt_q1["Is the procedure for Radiation planning for preoperative or definitive treatment?"]
#   fdg_mgmt_q2["Is the procedure for Single assessment of response to chemoradiation (as definitive treatment or prior to surgery) when performed at least 5 weeks after completion of therapy?"]
#   fdg_mgmt_q3["Can Standard imaging not be performed"]
#   fdg_mgmt_q4["Is Standard imaging nondiagnostic for recurrent or progressive disease?"]
#   pmc["Procedure Medically Necessary"]
#   start --> mri_chest
#   start --> mri_abdomen
#   start --> mri_pelvis
#   mri_pelvis --> is_ct_pelvis_contra
#   is_ct_pelvis_contra --> maybe_pelvic_disease_mri
#   maybe_pelvic_disease_mri --> pmc
#   start --> ct_chest
#   start --> ct_abdomen
#   start --> ct_pelvis
#   start --> fdg
#   ct_chest --> pmc
#   ct_abdomen --> pmc
#   mri_chest --> is_ct_contra
#   mri_abdomen --> is_ct_contra
#   is_ct_contra --> pmc
#   ct_pelvis --> maybe_pelvic_disease
#   maybe_pelvic_disease --> pmc
#   fdg --> fdg_diag
#   fdg_diag --> fdg_diag_q1
#   fdg_diag --> fdg_diag_q2
#   fdg_diag_q1 --> pmc
#   fdg_diag_q2 --> pmc
#   fdg --> fdg_mgmt
#   fdg_mgmt --> fdg_mgmt_q1
#   fdg_mgmt --> fdg_mgmt_q2
#   fdg_mgmt --> fdg_mgmt_q3
#   fdg_mgmt --> fdg_mgmt_q4
#   fdg_mgmt_q1 --> pmc
#   fdg_mgmt_q2 --> pmc
#   fdg_mgmt_q3 --> pmc
#   fdg_mgmt_q4 --> pmc
# **************************************************
# ```flowchart
# TD
#     A["Is there a documented case of esophageal or gastroesophageal junction cancer?"] -->|Yes| B["Is the imaging for diagnostic workup, management, or surveillance?"]
#     A -->|No| Z["Procedure not Medically Necessary"]
#
#     B -->|Diagnostic Workup| C["Is CT chest or CT abdomen indicated?"]
#     B -->|Management| G["Is CT chest or CT abdomen indicated?"]
#     B -->|Surveillance| K["Is CT chest or CT abdomen indicated?"]
#
#     C -->|Yes| D["Procedure Medically Necessary"]
#     C -->|No| E["Is CT pelvis indicated based on clinical suspicion for pelvic disease?"]
#
#     E -->|Yes| D
#     E -->|No| F["Is FDG-PET/CT indicated when standard imaging cannot be performed or does not demonstrate distant (M1) metastatic disease?"]
#
#     F -->|Yes| D
#     F -->|No| Z
#
#     G -->|Yes| H["Procedure Medically Necessary"]
#     G -->|No| I["Is CT pelvis indicated based on clinical suspicion for pelvic disease?"]
#
#     I -->|Yes| H
#     I -->|No| J["Is FDG-PET/CT indicated for radiation planning, single assessment of response to chemoradiation, or when standard imaging cannot be performed or is nondiagnostic for recurrent or progressive disease?"]
#
#     J -->|Yes| H
#     J -->|No| Z
#
#     K -->|Yes| L["Procedure Medically Necessary"]
#     K -->|No| M["Is CT pelvis indicated based on clinical suspicion for pelvic disease?"]
#
#     M -->|Yes| L
#     M -->|No| N["Procedure not Medically Necessary"]
# ```
# &&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&
# 0.2501 - Inflammatory conditions – not otherwise specified
# &&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&
# graph TD
#     A["Start"] -->B["Procedure Medically Necessary"]
# **************************************************
# ```flowchart
# flowchart TD
#     A["Is the condition Wegener’s granulomatosis or NMOSD?"] -->|Yes| B["Is advanced imaging required for diagnosis and management?"]
#     A -->|No| Z["Procedure not Medically Necessary"]
#     B -->|Yes| C["Is a CT of the orbit, sella, or posterior fossa and outer, middle, or inner ear needed?"]
#     B -->|No| Z
#     C -->|Yes| Y["Procedure Medically Necessary"]
#     C -->|No| D["Is an MRI of the orbit, face, and neck (soft tissue) needed?"]
#     D -->|Yes| Y
#     D -->|No| E["Is a CT of the paranasal sinuses and maxillofacial area needed?"]
#     E -->|Yes| Y
#     E -->|No| F["Is a CT of the soft tissue neck needed?"]
#     F -->|Yes| Y
#     F -->|No| G["Is an MRI of the temporomandibular joint for suspected inflammatory arthritis needed?"]
#     G -->|Yes| H["Have initial radiographs been performed?"]
#     G -->|No| Z
#     H -->|Yes| Y
#     H -->|No| Z
# ```
# &&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&
# &&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&
# Error: Sacroiliitis, not otherwise specified failed because: Graph type 'Undetermined' cannot be converted.
# **************************************************
# graph TD
#     A["Start"] --> B{"Is CT or MRI pelvis requested for sacroiliitis?"}
#     B -->|Yes| C{"Have pelvic or sacral radiographs been performed?"}
#     C -->|Yes| D{"Does the patient have a condition predisposing to sacroiliitis?"}
#     C -->|Yes| E{"Are radiographs equivocal for sacroiliitis?"}
#     D -->|Yes| F{"Are radiographs negative or equivocal for sacroiliitis?"}
#     F -->|Yes| G["Procedure Medically Necessary"]
#     E -->|Yes| G
# **************************************************
# ```flowchart
# flowchart TD
#     A["Have pelvic or sacral radiographs been performed?"] -->|Yes| B["Is there a condition predisposing to sacroiliitis (e.g., inflammatory bowel disease, psoriasis, or infection)?"]
#     A -->|No| G["Procedure not Medically Necessary"]
#     B -->|Yes| C["Are the radiographs negative or equivocal for sacroiliitis?"]
#     B -->|No| G
#     C -->|Yes| D["Procedure Medically Necessary"]
#     C -->|No| G
#     E["Are the radiographs equivocal for sacroiliitis?"] -->|Yes| D
#     E -->|No| G
# ```
# &&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&
# 0.6776 - Appendicitis
# 0.7560 - Acute aortic syndrome
# 0.6217 - Thyroid Cancer
# 0.4448 - Hydronephrosis
# &&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&
# flowchart TD
#   start["Start"]
#   ct["CT Requested?"]
#   mri["MRI Requested?"]
#   pediatric["Is the patient a child?"]
#   ct_not_performable["Can a CT not be performed?"]
#   ct_not_diagnostic["Is a CT non diagnostic"]
#   pmc["Procedure Medically Necessary"]
#   start --> ct
#   ct --> pmc
#   start --> mri
#   mri --> pediatric
#   mri --> ct_not_performable
#   mri --> ct_not_diagnostic
#   pediatric --> pmc
#   ct_not_performable --> pmc
#   ct_not_diagnostic --> pmc
# **************************************************
# ```flowchart
# flowchart TD
#     A["Has an ultrasound been performed?"] -->|Yes| B["Was the ultrasound diagnostic?"]
#     A -->|No| C["Procedure not Medically Necessary"]
#     B -->|Yes| C
#     B -->|No| D["Is CT abdomen or CT abdomen/pelvis available?"]
#     D -->|Yes| E["Procedure Medically Necessary"]
#     D -->|No| F["Is MRI abdomen and pelvis (MR urogram) available?"]
#     F -->|Yes| G["Is the patient pediatric or is CT nondiagnostic?"]
#     F -->|No| H["Procedure not Medically Necessary"]
#     G -->|Yes| E
#     G -->|No| H
# ```
# &&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&
# 0.8047 - Nontraumatic spinal fractures
# 0.6127 - Bladder and Urothelial Cancers
# &&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&
# Error: Bell’s palsy (peripheral facial nerve palsy) failed because: 'Yes'
# **************************************************
# graph TD
#     start["Start"]
#     addl_findings["Are there additional neurologic findings suggestive of intracranial pathology?"]
#     pmc["Procedure Medically Necessary"]
#     6wks["Have symptoms persisted beyond 6 weeks?"]
#     no_mri["Is MRI contraindicated?"]
#     ct["Is CT brain being requested?"]
#     mri["Is MRI Brain being requested?"]
#
#     start --> addl_findings
#     start --> 6wks
#     addl_findings --> ct
#     addl_findings --> mri
#     6wks --> ct
#     6wks --> mri
#     mri --> pmc
#     ct --> no_mri
#     no_mri --> pmc
# **************************************************
# ```flowchart
# flowchart TD
#     A["Are there additional neurologic findings suggestive of intracranial pathology (atypical presentation)?"]
#     B["Have symptoms persisted beyond 6 weeks in the absence of additional neurologic findings?"]
#     C["Can MRI be performed?"]
#     D["Procedure Medically Necessary"]
#     E["Procedure not Medically Necessary"]
#     F["CT brain when MRI cannot be performed"]
#     G["MRI brain"]
#
#     A -- Yes --> C
#     A -- No --> B
#     B -- Yes --> C
#     B -- No --> E
#     C -- Yes --> G
#     C -- No --> F
#     G --> D
#     F --> D
# ```
# &&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&
# &&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&
# Error: Intra-cardiac and para-cardiac masses and tumors failed because: Graph type 'Undetermined' cannot be converted.
# **************************************************
#
# graph TD
#     A["Start"]
#     B["Is Cardiac MRI requested?"]
#     C["Is there a suspected cardiac or para-cardiac mass?"]
#     D["Is it suggested by transthoracic echocardiography?"]
#     E["Is it suggested by transesophageal echocardiography?"]
#     F["Is it suggested by blood pool imaging?"]
#     G["Is it suggested by contrast ventriculography?"]
#     H["Has the patient NOT undergone cardiac MRI or cardiac CT within the preceding 60 days?"]
#     I["Is there an established cardiac or para-cardiac mass?"]
#     J["Is the patient clinically unstable?"]
#     K["Has the patient NOT undergone cardiac MRI or cardiac CT within the preceding year?"]
#     L["Has the patient undergone treatment within the preceding year?"]
#     M["Has the patient NOT had cardiac MRI or cardiac CT within the preceding 60 days?"]
#     N["Procedure Medically Necessary"]
#
#     A --> B
#     B --> C
#     C --> D
#     C --> E
#     C --> F
#     C --> G
#     D --> H
#     E --> H
#     F --> H
#     G --> H
#     H --> N
#     B --> I
#     I --> J
#     J --> N
#     I --> K
#     K --> N
#     I --> L
#     L --> M
#     M --> N
#
# **************************************************
# ```flowchart
# flowchart TD
#     A["Is there a suspected cardiac or para-cardiac mass suggested by transthoracic echocardiography, transesophageal echocardiography, blood pool imaging or contrast ventriculography?"] -->|Yes| B["Has the patient undergone cardiac CT or cardiac MRI within the preceding 60 days?"]
#     A -->|No| G["Procedure not Medically Necessary"]
#     B -->|Yes| G
#     B -->|No| F["Procedure Medically Necessary"]
#
#     C["Is there an established cardiac or para-cardiac mass and is the patient clinically unstable?"] -->|Yes| F
#     C -->|No| D["Is the patient clinically stable and has not undergone cardiac CT or cardiac MRI within the preceding year?"]
#
#     D -->|Yes| F
#     D -->|No| E["Has the patient undergone treatment (chemotherapy, radiation therapy, thrombolysis, anticoagulation or surgery) within the preceding year and not had cardiac CT or cardiac MRI within the preceding 60 days?"]
#
#     E -->|Yes| F
#     E -->|No| G
# ```
# &&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&
# &&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&
# Error: Chronic lymphocytic leukemia or small lymphocytic lymphoma failed because: Graph type 'Undetermined' cannot be converted.
# **************************************************
# flowchart TD
#   A["Start"]
#   B["Is the request for CT chest?"]
#   C["Is the request for CT abdomen and pelvis?"]
#   D["Is this for diagnostic workup?"]
#   E["Is this for management of a known condition?"]
#   F["Is this for surveillance?"]
#   G["Is the patient experiencing symptoms?"]
#   H["Is this to evaluate bulky disease?"]
#   I["Is the request for a MRI?"]
#   J["Is CT containdicated or expected to be suboptimal (due to contrast allergy or contrast nephrotoxicity)?"]
#   K["Is the request for a FDG-PET/CT?"]
#   L["Is this for diagnostic workup?"]
#   M["Is this for management of a known condition?"]
#   N["Is there a suspicion of Richter's transformation?"]
#   O["Is PET utilized to direct biopsy?"]
#   Z["Procedure Medically Necessary"]
#
#   A-->B
#   A-->C
#   B-->D
#   C-->D
#   D-->Z
#   B-->E
#   C-->E
#   B-->F
#   C-->F
#   E-->G
#   E-->H
#   F-->G
#   F-->H
#   G-->Z
#   H-->Z
#   A-->I
#   I-->J
#   J-->D
#   J-->E
#   J-->F
#   A-->K
#   K-->L
#   K-->M
#   L-->N
#   M-->N
#   N-->O
#   O-->Z
# **************************************************
# ```flowchart
# flowchart TD
#     A["Is there suspicion of Richter’s transformation?"] -->|Yes| B["Is PET utilized to direct biopsy?"]
#     A -->|No| C["Procedure not Medically Necessary"]
#     B -->|Yes| D["Procedure Medically Necessary"]
#     B -->|No| C
#     E["Are there symptoms or is there a need to evaluate bulky disease?"] -->|Yes| F["Is CT chest, abdomen, or pelvis indicated?"]
#     E -->|No| C
#     F -->|Yes| D
#     F -->|No| C
#     G["Is MRI considered necessary due to CT contraindication or expected suboptimal results?"] -->|Yes| D
#     G -->|No| C
# ```
# &&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&
# 0.9520 - Sports hernia (athletic pubalgia)
# 0.5555 - Other thoracic mass lesions
# &&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&
# flowchart TD
#   A["start"]
#   B["Is the patient an adult?"]
#   C["Is the patient pediatric?"]
#   D["Is the request for CT chest?"]
#   E["Is the request for MRI chest?"]
#   F["Is the request for evaluation of mediastinal and hilar masses?"]
#   G["Is CT insufficient for problem solving?"]
#   H["Is the request for evaluation of chest wall extension in Pancoast tumor?"]
#   I["Does the patient have mediastinal mass?"]
#   J["Does the patient have pancoast tumor?"]
#   K["Does the patient have pleural mass?"]
#   L["Does the patient have thymoma?"]
#   M["Does the patient have benign tumors?"]
#   N["Medically Necessary"]
#   A-->B
#   A-->C
#   B-->D
#   B-->E
#   E-->F
#   F-->G
#   E-->H
#   D-->I
#   G-->I
#   H-->I
#   C-->I
#   D-->J
#   G-->J
#   H-->J
#   C-->J
#   D-->K
#   G-->K
#   H-->K
#   C-->K
#   D-->L
#   G-->L
#   H-->L
#   C-->L
#   C-->M
#   I-->N
#   J-->N
#   K-->N
#   L-->N
#   M-->N
# **************************************************
# ```flowchart
# TD
#     A["Is there a mediastinal mass?"] -->|Yes| B["Procedure Medically Necessary"]
#     A -->|No| C["Is there a Pancoast tumor?"]
#     C -->|Yes| B
#     C -->|No| D["Is there a pleural mass?"]
#     D -->|Yes| B
#     D -->|No| E["Is there a thymoma?"]
#     E -->|Yes| B
#     E -->|No| F["Is the patient pediatric with benign tumors?"]
#     F -->|Yes| B
#     F -->|No| G["Procedure not Medically Necessary"]
# ```
# &&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&
# 0.8065 - Ovarian Cancer – All Variants > FDG-PET/CT
# 0.5300 - Bladder or urethral diverticula
# &&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&
# flowchart TD
#     A["Start"]
#     B["Is the request for diagnosis?"]
#     C["Is the request for management?"]
#     AA["Procedure Medically Necessary"]
#     A-->B
#     B-->AA
#     A-->C
#     C-->AA
# **************************************************
# ```flowchart
# flowchart TD
#     A["Is there a suspicion of bladder or urethral diverticula?"] -->|Yes| B["Is advanced imaging required for diagnosis and management?"]
#     A -->|No| C["Procedure not Medically Necessary"]
#     B -->|Yes| D["Is MRI pelvis the chosen imaging study?"]
#     B -->|No| C
#     D -->|Yes| E["Procedure Medically Necessary"]
#     D -->|No| C
# ```
# &&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&
# 0.7702 - Non-specific mid-back pain (thoracic)
# 0.9429 - Stenosis or occlusion of the abdominal aorta or branch vessels, not otherwise specified
# 0.6305 - Neck mass (including lymphadenopathy)
# 42
# 32

# %%
print("CLAUDE")
print(score_total)
print(score_total / count)
print(score_total / match_count)
# Out:
# CLAUDE
# 20.784501185743046
# 0.4948690758510249
# 0.6495156620544702

# %%
print("gpt-4o-latest")
print(score_total)
print(score_total / count)
print(score_total / match_count)
# Out:
# gpt-4o-latest
# 20.784501185743046
# 0.4948690758510249
# 0.6495156620544702
