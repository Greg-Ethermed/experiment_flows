# %%
import anthropic
import os
from dotenv import load_dotenv
import openai

load_dotenv(".env")
# Out:
# False

# %%
def guideline_to_flowchart_prompt(
    reformatted_guidelines: str,
) -> dict[str, str]:
    """
    Convert reformated guidelines to flowchart prompt.

    Args:
        reformatted_guidelines (str): Reformatted guidelines.

    Returns:
        Dict[str, str]: OpenAI messages with reformatted guidelines
    """

    # Payload for the request
    payload = {
        "messages": [
            {
                "role": "user",
                "content": [
                    {
                        "type": "text",
                        "text": "Create a flowchart in flowchart TD syntax from given medical \
                                guidelines. You need to convert each step of the guideline to question \
                                so that it could be answered 'Yes' or 'No' \
                                Pay close attention to details, since we do not want to omit anything. \
                                Best, go over guidelines and reason step by step. \
                                Make sure everything ends with either: \
                                'Procedure Medically Necessary' or 'Procedure not Medically Necessary' \
                                Also, make sure you encapsulate all nodes into square brackets: '[' \
                                and labels into double quotes. \
                                Please output generated flowchart only without any additional comments. \
                                Guidelines text: \n\n ``` "
                        + reformatted_guidelines
                        + " ```",
                    },
                ],
            },
        ],
    }

    return payload["messages"]

def extract_necessary_requirements_assertion_prompt(parsed_guideline: str) -> str:
    """
    Extracts the necessary requirements assertion prompt from the parsed guideline.

    Args:
        parsed_guideline (str): The parsed guideline.

    Returns:
        str: The necessary requirements assertion prompt.

    """
    extract_requirements_prompt = [
        {
            "role": "system",
            "content": """Please create a flowchart diagramming whether the stated procedure is \
                medically necessary given the following information. Ensure that there are no parenthesis \
                in the labels, and omit subgraphs and any nodes other than questions (diamonds in \
                flowchart parlance) that could be answered true or false by reading through a medical \
                pre-auth request. If the input is empty, return None.""",
        },
        {
            "role": "user",
            "content": """#### Craniocervical junction abnormalities\n\n_Includes atlantoaxial and \
                occipital instability as well as basilar\ninvagination_\n\nAdvanced imaging of the \
                spine is considered medically necessary for diagnosis\nand management following \
                nondiagnostic radiographs in persons with **ANY** of\nthe following high-risk \
                conditions:\n\n-\n\nDown syndrome\n\n-\n\nGrisel syndrome\n\n-\n\nSkeletal \
                dysplasia\n\n-\n\nRheumatoid arthritis\n\n**IMAGING STUDY**\n\n-\n\nCT cervical \
                spine\n\n-\n\nMRI cervical spine\n\n##### Rationale\n\nRheumatoid arthritis is a \
                systemic inflammatory disease that affects the\ncervical spine in up to 80% of \
                cases resulting in craniocervical instability,\nmost commonly from atlantoaxial \
                subluxation. MRI is the most sensitive exam to\nestablish the diagnosis,1 which \
                carries an increased risk of mortality and\nmorbidity in rheumatoid arthritis \
                patients,2 and lifetime radiological follow\nup may be required.\n""",
        },
        {
            "role": "assistant",
            "content": """flowchart TD
                A["Does the patient have craniocervical junction abnormalities?"] \
                    -->|Yes| B["Have nondiagnostic radiographs been performed?"]
                A -->|No| End1["Procedure not medically necessary"]
                B -->|Yes| C["Does the patient have any of the high-risk conditions?"]
                B -->|No| End1
                C -->|Yes| D["Down syndrome?"]
                C -->|No| End1
                D -->|Yes| E["Advanced imaging CT or MRI is medically necessary"]
                D -->|No| F["Grisel syndrome?"]
                F -->|Yes| E
                F -->|No| G["Skeletal dysplasia?"]
                G -->|Yes| E
                G -->|No| H["Rheumatoid arthritis?"]
                H -->|Yes| E
                H -->|No| End1
                E --> I["CT cervical spine"]
                E --> J["MRI cervical spine"]""",
        },
        {"role": "user", "content": parsed_guideline},
    ]

    return extract_requirements_prompt

# %%
client = anthropic.Anthropic(
    api_key=os.getenv("CLAUDE_KEY")
)

# %%
import json
import hashlib
import diskcache as dc

cache = dc.Cache("data")

def hash_parameters(*args, **kwargs):
    """Create a hash of the function parameters."""
    kwargs.pop("response_format", None)
    params = json.dumps((args, kwargs))
    return hashlib.md5(params.encode()).hexdigest()

def cached(func):
    def wrapper(*args, **kwargs):
        cache_kwargs = kwargs.copy()
        if "client" in cache_kwargs:
            cache_kwargs.pop("client")
        key = f"{func.__name__}:{hash_parameters(*args, **cache_kwargs)}"
        if key in cache:
            return cache[key]
        result = func(*args, **kwargs)
        cache[key] = result
        return result

    return wrapper

# %%
@cached
def get_claude_response(messages):
    response = client.messages.create(
        model="claude-3-5-sonnet-20240620",
        max_tokens=1024,
        messages=messages,
        temperature=0.0,
        top_p=0.95,
    )
    return response

# %%
import backoff
import requests


# Implement backoff logic that will retry the request
@backoff.on_predicate(
    backoff.runtime,  # Exponential backoff
    predicate=lambda r: r.status_code == 429,
    value=lambda r: int(r.headers.get("Retry-After")),
)
@cached
def get_gpt_response_api(prompt, model_name, endpoint, key, temperature):
    headers = {
        # "authorization": f"Bearer {key}",
        "api-key": key,
        "Content-Type": "application/json"
    }

    modified_schema = {
        "type": "object",
        "required": ["results"],
        "additionalProperties": False,
        "properties": {
            "results": {
                "type": "object",
                    "required": ["summary", "discussion", "answers"],
                    "additionalProperties": False,
                    "properties": {
                        "summary": {
                            "type": "string",
                            "description": "Summary of the patient information focusing on aspects that are relevant to the question(s)"
                        },
                        "discussion": {
                            "type": "string",
                            "description": "How does the provided information help or not help to answer the questions?"
                        },
                        "answers": {
                            "type": "array",
                            "items": {
                                "type": "object",
                                "required": ["answer", "supporting evidence"],
                                "additionalProperties": False,
                                "properties": {
                                    "answer": {
                                        "type": "string",
                                        "description": "The correct answer choice among the multiple choices"
                                    },
                                    "supporting evidence": {
                                        "type": "string",
                                        "description": "A direct quote from the patient information that supports the answer if one exists."
                                    }
                                }
                            }
                        }
                    }
                }
            }
        }

    # The data being sent in the request, including the schema and prompt
    data = {
        "model": model_name,
        "messages": prompt,
        "temperature": temperature,
        # "logprobs": True,
        # "top_logprobs": 5,
        # "response_format": {
        #     "type": "json_schema",
        #     "json_schema": {
        #         "name": "QuestionAnswers",
        #         "strict": True,
        #         "schema": modified_schema
        #     }
        # }
    }

    # Send the request
    print(f"ENDPOINT: {endpoint}")
    response = requests.post(endpoint, headers=headers, json=data)
    return response

@cached
def get_gpt_response(messages, model_name, endpoint, key):
    try:
        return openai.ChatCompletion.create(
            api_key=key,
            api_base=endpoint,
            api_version=os.getenv("AZURE_OPENAI_API_VERSION"),
            api_type="azure",
            engine=model_name,
            messages=messages,
            temperature=0.0,
            top_p=0.95,
            frequency_penalty=0,
            presence_penalty=0,
            stop=None,
        )
    except openai.InvalidRequestError:
        return {"choices": [{"message": {"content": "Question 1: The request was deemed invalid and likely violated the content filters."}}]}

# %%
url = "https://guidelines.carelonmedicalbenefitsmanagement.com/imaging-of-the-chest-2024-04-14/"
markdown = "#Other thoracic mass lesions Advanced imaging is considered medically necessary for diagnosis and management of **ANY** of the following findings or conditions: - Mediastinal mass (see separate indication for lymphadenopathy) - Pancoast tumor - Pleural mass - Thymoma - Benign tumors (pediatric only) **IMAGING STUDY** \*\*_ADULT_ \*\* - CT chest - MRI chest for evaluation of mediastinal and hilar masses when CT is insufficient for problem solving or for evaluation of chest wall extension in Pancoast tumor \*\*_PEDIATRIC_ \*\* - CT or MRI chest"
topic = "Other thoracic mass lesions"
def get_mermaid_from_gpt(topic, markdown):
    message = guideline_to_flowchart_prompt(markdown)
    response = get_gpt_response(message, 
                                    model_name="gpt-4o-latest", 
                                    endpoint=os.getenv("AZURE_OPENAI_ENDPOINT_EAST2"), 
                                    key=os.getenv("AZURE_OPENAI_API_KEY_EAST2"), 
                                    # temperature=0.0
                                    )
    return response["choices"][0]["message"]["content"]

def get_mermaid_from_claude(topic, markdown):
    message = guideline_to_flowchart_prompt(markdown)
    response = get_claude_response(message)
    return response.content[0].text

import time
start_time = time.time()
get_mermaid_from_claude(topic, markdown)
print(f"Finished in {(time.time()-start_time):.4f} seconds")
# Out:
# Finished in 0.0008 seconds
# <>:2: SyntaxWarning: invalid escape sequence '\*'
# <>:2: SyntaxWarning: invalid escape sequence '\*'
# /tmp/ipykernel_29873/2641030083.py:2: SyntaxWarning: invalid escape sequence '\*'
#   markdown = "#Other thoracic mass lesions Advanced imaging is considered medically necessary for diagnosis and management of **ANY** of the following findings or conditions: - Mediastinal mass (see separate indication for lymphadenopathy) - Pancoast tumor - Pleural mass - Thymoma - Benign tumors (pediatric only) **IMAGING STUDY** \*\*_ADULT_ \*\* - CT chest - MRI chest for evaluation of mediastinal and hilar masses when CT is insufficient for problem solving or for evaluation of chest wall extension in Pancoast tumor \*\*_PEDIATRIC_ \*\* - CT or MRI chest"

# %%
import scorcery
import scorcery.create_local_overrides

override_path = "overrides.db"
if not os.path.isfile(override_path):
    scorcery.create_local_overrides.migrate_postgres_to_sqlite(override_path)

# %%
import re


test_string = """```mermaid
flowchart TD
    [A] --> |Yes| [B]
    [A] --> |No| [C]
    [B] --> |Yes| [D]
    [B] --> |No| [E]
    [C] --> |Yes| [F]
    [C] --> |No| [G]
    [D] --> [H]
    [E] --> [I]
    [F] --> [J]
    [G] --> |Yes| [K]
    [G] --> |No| [L]
    [H] --> [M]
    [I] --> [N]
    [J] --> [O]
    [K] --> [P]
    [L] --> [Q]

    [A]{"Is the patient an adult?"}
    [B]{"Does the patient have pain with neurologic findings suggesting thoracic or lumbar nerve root or cord compression that has not previously been imaged or has progressed since imaging was performed?"}
    [C]{"Is the patient pediatric?"}
    [D]{"Is the patient a potential candidate for spine intervention?"}
    [E]{"Does the patient have pain without a neurologic component that has not responded to at least 6 weeks of conservative management?"}
    [F]{"Does the patient have localized or radicular pain not explained by radiograph and not responsive to a course of conservative management?"}
    [G]{"Does the patient have pain with evidence of nerve root or cord compression?"}
    [H]{"Procedure Medically Necessary"}
    [I]{"Is the patient a potential candidate for spine intervention?"}
    [J]{"Procedure Medically Necessary"}
    [K]{"Procedure Medically Necessary"}
    [L]{"Procedure not Medically Necessary"}
    [M]{"MRI thoracic spine or CT thoracic spine (excluding CT discography) when MRI cannot be performed or is nondiagnostic"}
    [N]{"Procedure Medically Necessary"}
    [O]{"MRI thoracic spine or CT thoracic spine (excluding CT discography) when MRI cannot be performed or is nondiagnostic"}
    [P]{"MRI thoracic spine or CT thoracic spine (excluding CT discography) when MRI cannot be performed or is nondiagnostic"}
    [Q]{"Procedure not Medically Necessary"}
```"""
def fix_nodes_in_brackets(response):
    new_response = []
    for line in response.split("\n"):
        pattern = r'\[([^\[\]]{1,2})\]'
        line = re.sub(pattern, r'\1', line)
        new_response.append(line)
    return "\n".join(new_response)

fix_nodes_in_brackets(test_string)
# Out:
# '```mermaid\nflowchart TD\n    A --> |Yes| B\n    A --> |No| C\n    B --> |Yes| D\n    B --> |No| E\n    C --> |Yes| F\n    C --> |No| G\n    D --> H\n    E --> I\n    F --> J\n    G --> |Yes| K\n    G --> |No| L\n    H --> M\n    I --> N\n    J --> O\n    K --> P\n    L --> Q\n\n    A{"Is the patient an adult?"}\n    B{"Does the patient have pain with neurologic findings suggesting thoracic or lumbar nerve root or cord compression that has not previously been imaged or has progressed since imaging was performed?"}\n    C{"Is the patient pediatric?"}\n    D{"Is the patient a potential candidate for spine intervention?"}\n    E{"Does the patient have pain without a neurologic component that has not responded to at least 6 weeks of conservative management?"}\n    F{"Does the patient have localized or radicular pain not explained by radiograph and not responsive to a course of conservative management?"}\n    G{"Does the patient have pain with evidence of nerve root or cord compression?"}\n    H{"Procedure Medically Necessary"}\n    I{"Is the patient a potential candidate for spine intervention?"}\n    J{"Procedure Medically Necessary"}\n    K{"Procedure Medically Necessary"}\n    L{"Procedure not Medically Necessary"}\n    M{"MRI thoracic spine or CT thoracic spine (excluding CT discography) when MRI cannot be performed or is nondiagnostic"}\n    N{"Procedure Medically Necessary"}\n    O{"MRI thoracic spine or CT thoracic spine (excluding CT discography) when MRI cannot be performed or is nondiagnostic"}\n    P{"MRI thoracic spine or CT thoracic spine (excluding CT discography) when MRI cannot be performed or is nondiagnostic"}\n    Q{"Procedure not Medically Necessary"}\n```'

# %%
import scorcery.final_db
from peewee import SqliteDatabase
import scorcery.final_db.guideline_repo
import scorcery.flows
import graph_tools


target_db = SqliteDatabase(override_path)
count = 0
match_count = 0
score_total = 0
target_title = "Penile, Vaginal, and Vulvar Cancers"
for target in scorcery.final_db.guideline_repo.GuidelineRepo.all(target_db):
    count += 1
    response = get_mermaid_from_claude(target.title, target.id)
    try:
        response = fix_nodes_in_brackets(response)
        experiment_flow = graph_tools.graph.EMGraph.from_mermaid(response)
        experiment_flow.as_logic_graph()
        score = scorcery.flows.score_flows(target.flow, experiment_flow.get_mermaid_text())
        print(f"{score:.4f} - {target.title}")
        score_total += score
        match_count += 1
        # if score < 0.6:
        #     print("&"*100)
        #     print(target.flow)
        #     print("*"*50)
        #     print(response)
        #     print("^"*100)
        #     print(experiment_flow.get_mermaid_text())
        #     print("^"*100)
        #     print("&"*100)
        if 
    
    except Exception as e:
        print("&"*100)
        print(f"Error: {target.title} failed because: {e}")
        print("*"*50)
        print(target.flow)
        print("*"*50)
        print(response)
        print("&"*100)
    
    # break

print(count)
print(match_count)
# Out:
# 0.7160 - Head and Neck Cancer
# &&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&
# Error: Lower extremity pain, not otherwise specified failed because: list index out of range
# **************************************************
# graph TD
#     A["Start"] --> B["Is advanced imaging for lower extremity pain requested?"]
#     B -->|Yes| C["Is the pain persistent?"]
#     C -->|Yes| D["Are radiographs nondiagnostic?"]
#     D -->|Yes| E["Has there been a failure of at least 6 weeks of conservative management?"]
#     E -->|Yes| F["Procedure Medically Necessary"]
# **************************************************
# ```mermaid
# flowchart TD
#     A --> |Yes| B
#     A --> |No| C
#     B --> |Yes| D
#     B --> |No| C
#     D --> |Yes| E
#     D --> |No| C
#
#     A{"Are radiographs nondiagnostic (without moderate/severe osteoarthritis or normal)?"}
#     B{"Has there been failure of at least 6 weeks of conservative management?"}
#     C["Procedure not Medically Necessary"]
#     D{"Is MRI of lower extremity possible?"}
#     E["Procedure Medically Necessary: MRI lower extremity"]
#     F["Procedure Medically Necessary: CT lower extremity"]
#
#     E --> F
# ```
# &&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&
# 0.7643 - Pulmonary embolism
# 0.7670 - Penile, Vaginal, and Vulvar Cancers
# &&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&
# Error: Temporomandibular joint dysfunction failed because: Graph type 'Undetermined' cannot be converted.
# **************************************************
# graph TD
#     A["Start"]
#     B["Does the patient have mechanical symptoms (such as locking, popping, or clicking) of the temporomandibular joint?"]
#     C["Has the patient completed a six-week course of conservative treatment with no improvement in symptoms?"]
#     D["Has the patient used nonsteroidal anti-inflammatory drugs or acetaminophen?"]
#     E["Has the patient had a short-term trial of soft diet and proper chewing techniques?"]
#     F["Has the patient used an oral appliance (such as a bite block)?"]
#     G["Is surgical intervention being considered for the patient?"]
#     H["Procedure Medically Necessary"]
#     A-->B
#     B-->C
#     C-->D
#     D-->E
#     E-->F
#     F-->G
#     G-->H
# **************************************************
# ```mermaid
# flowchart TD
#     A --> |Yes| B
#     A --> |No| C
#     B --> |Yes| D
#     B --> |No| C
#     D --> |Yes| E
#     D --> |No| C
#     E --> |Yes| F
#     E --> |No| G
#
#     A{"Have mechanical symptoms (locking, popping, or clicking) not improved with a six-week course of conservative treatment?"}
#     B{"Is surgical intervention being considered?"}
#     C["Procedure not Medically Necessary"]
#     D{"Is imaging needed for diagnosis or management?"}
#     E{"Is evaluation for intraarticular loose bodies or temporomandibular joint osteoarthritis required?"}
#     F["CT paranasal sinuses and maxillofacial area - Procedure Medically Necessary"]
#     G{"Is evaluation of internal derangement or disc displacement required?"}
#     G --> |Yes| H
#     G --> |No| C
#     H["MRI temporomandibular joint - Procedure Medically Necessary"]
# ```
# &&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&
# 0.6318 - Weight loss
# &&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&
# Error: Chest wall mass failed because: Graph type 'Undetermined' cannot be converted.
# **************************************************
# graph TD
#     A["Start"] -->|True| B{"Is there a palpable chest wall mass?"}
#     A -->|True| F{"Was a chest wall mass identified on prior imaging?"}
#     A -->|True| H{"Is preoperative planning required following a biopsy?"}
#     B -->|True| C{"Is the radiograph nondiagnostic?"}
#     B -->|True| D{"Is the ultrasound nondiagnostic?"}
#     C -->|True| E["Procedure Medically Necessary"]
#     D -->|True| E
#     F -->|True| G{"Is further information needed for biopsy or surgery?"}
#     G -->|True| E
#     H -->|True| E
# **************************************************
# ```mermaid
# flowchart TD
#     A["Is there a palpable chest wall mass with nondiagnostic radiograph or ultrasound?"]
#     B["Was a chest wall mass identified on prior imaging and further information is needed to determine need for biopsy or surgery?"]
#     C["Is preoperative planning needed following biopsy?"]
#     D["Is the mass a breast mass (including gynecomastia)?"]
#     E["Procedure Medically Necessary"]
#     F["Procedure not Medically Necessary"]
#     G["Refer to Oncologic Imaging guidelines for breast cancer"]
#
#     A -->|Yes| E
#     A -->|No| B
#     B -->|Yes| E
#     B -->|No| C
#     C -->|Yes| E
#     C -->|No| D
#     D -->|Yes| G
#     D -->|No| F
# ```
# &&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&
# 0.2651 - Pulmonary hypertension
# &&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&
# flowchart TD
#     C["Start"] --> A{"Is this to evaluate\nsuspected pulmonary\nhypertension (including CTEPH)?"}
#     C --> B{"Is this to evaluate disease extent\nafter diagnosis of CTEPH in patients\nbeing considered for surgery?"}
#
#     A --> |Yes| MN["Procedure Medically Necessary"]
#     B --> |Yes| MN
# **************************************************
# flowchart TD
#     [Start] --> [Is advanced imaging being considered for diagnosis and management of pulmonary hypertension?]
#     [Is advanced imaging being considered for diagnosis and management of pulmonary hypertension?] --> |Yes| [Is it to evaluate suspected pulmonary hypertension, including chronic thromboembolic pulmonary hypertension (CTEPH)?]
#     [Is advanced imaging being considered for diagnosis and management of pulmonary hypertension?] --> |No| [Procedure not Medically Necessary]
#     [Is it to evaluate suspected pulmonary hypertension, including chronic thromboembolic pulmonary hypertension (CTEPH)?] --> |Yes| [Procedure Medically Necessary]
#     [Is it to evaluate suspected pulmonary hypertension, including chronic thromboembolic pulmonary hypertension (CTEPH)?] --> |No| [Is it to evaluate disease extent after diagnosis of chronic thromboembolic pulmonary hypertension (CTEPH) in patients being considered for surgery?]
#     [Is it to evaluate disease extent after diagnosis of chronic thromboembolic pulmonary hypertension (CTEPH) in patients being considered for surgery?] --> |Yes| [Procedure Medically Necessary]
#     [Is it to evaluate disease extent after diagnosis of chronic thromboembolic pulmonary hypertension (CTEPH) in patients being considered for surgery?] --> |No| [Procedure not Medically Necessary]
#     [Procedure Medically Necessary] --> [Is CT chest or CTA chest being considered?]
#     [Is CT chest or CTA chest being considered?] --> |Yes| [Procedure Medically Necessary]
#     [Is CT chest or CTA chest being considered?] --> |No| [Procedure not Medically Necessary]
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# flowchart TD;
#   _start_["start"]
#   _end_["end"]
#   flowchart["flowchart"]
#   _start_-->|Yes| flowchart
#   flowchart-->|Yes| _end_
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# &&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&
# 0.3740 - Coronary artery calcium (CAC)
# &&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&
# graph TD
#     A["Start"] --> B["Is CAC testing requested?"]
#     B -->|Yes| C["Is patient between 40 and 75 years of age?"]
#     C -->|Yes| D["Does patient have no known atheromatous vascular disease?"]
#     D -->|Yes| E["Is patient non-diabetic?"]
#     E -->|Yes| F["Is LDL cholesterol between 70 and 190 mg/dL?"]
#     F -->|Yes| G["Is 10-year ASCVD risk between 5% and 20%?"]
#     G -->|Yes| H["No family history of premature ASCVD?"]
#     H -->|Yes| I["No persistently elevated LDL (≥160 mg/dL)?"]
#     I -->|Yes| J["No persistently elevated triglycerides (>175 mg/dL)?"]
#     J -->|Yes| K["No metabolic syndrome?"]
#     K -->|Yes| L["No chronic kidney disease?"]
#     L -->|Yes| M["No chronic inflammatory condition?"]
#     M -->|Yes| N["No history of menopause before age 40?"]
#     N -->|Yes| O["No history of preeclampsia?"]
#     O -->|Yes| P["Not of high-risk race/ethnicity?"]
#     P -->|Yes| Q["No elevated high-sensitivity CRP, if measured?"]
#     Q -->|Yes| R["No elevated lipoprotein(a), if measured?"]
#     R -->|Yes| S["No elevated apolipoprotein B, if measured?"]
#     S -->|Yes| T["No ankle-brachial index <0.9, if measured?"]
#     T -->|Yes| U["Procedure Medically Necessary"]
#
# **************************************************
# flowchart TD
#     ["Is there known atheromatous vascular disease?"] --> |No| ["Is the patient diabetic?"]
#     ["Is there known atheromatous vascular disease?"] --> |Yes| ["Procedure not Medically Necessary"]
#     ["Is the patient diabetic?"] --> |No| ["Is the patient's age between 40 and 75 years (inclusive)?"]
#     ["Is the patient diabetic?"] --> |Yes| ["Procedure not Medically Necessary"]
#     ["Is the patient's age between 40 and 75 years (inclusive)?"] --> |Yes| ["Is LDL cholesterol between 70 mg/dL and 190 mg/dL (inclusive)?"]
#     ["Is the patient's age between 40 and 75 years (inclusive)?"] --> |No| ["Procedure not Medically Necessary"]
#     ["Is LDL cholesterol between 70 mg/dL and 190 mg/dL (inclusive)?"] --> |Yes| ["Is 10-year risk (using ASCVD Pooled Cohort Equations) between 5% and 20% (inclusive)?"]
#     ["Is LDL cholesterol between 70 mg/dL and 190 mg/dL (inclusive)?"] --> |No| ["Procedure not Medically Necessary"]
#     ["Is 10-year risk (using ASCVD Pooled Cohort Equations) between 5% and 20% (inclusive)?"] --> |Yes| ["Does the patient have ANY of the following conditions?"]
#     ["Is 10-year risk (using ASCVD Pooled Cohort Equations) between 5% and 20% (inclusive)?"] --> |No| ["Procedure not Medically Necessary"]
#     ["Does the patient have ANY of the following conditions?"] --> |No| ["Procedure Medically Necessary"]
#     ["Does the patient have ANY of the following conditions?"] --> |Yes| ["Procedure not Medically Necessary"]
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# flowchart TD;
#   _start_["start"]
#   _end_["end"]
#   flowchart["flowchart"]
#   _start_-->|Yes| flowchart
#   flowchart-->|Yes| _end_
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# &&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&
# &&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&
# Error: Aneurysm, intracranial failed because: 'N'
# **************************************************
# graph TD
#     A["Start"] --> B["Is screening for intracranial aneurysm requested?"]
#     A --> C["Is diagnosis of clinically suspected intracranial aneurysm requested?"]
#     A --> D["Is management of known intracranial aneurysm requested?"]
#     A --> E["Is surveillance of known intracranial aneurysm requested?"]
#
#     B --> F["Does the patient have two or more first-degree relatives with intracranial aneurysm or subarachnoid hemorrhage?"]
#     B --> G["Does the patient have a condition associated with an increased risk of intracranial aneurysm?"]
#     B --> H["Does the patient have known fibromuscular dysplasia?"]
#
#     C --> I["Are there CT or MRI findings suspicious for aneurysm?"]
#     C --> J["Does the patient have neurologic signs or symptoms suggestive of intracranial aneurysm?"]
#
#     J --> K["Does the patient have at least one first-degree relative with intracranial aneurysm or subarachnoid hemorrhage?"]
#     J --> L["Does the patient have a condition associated with an increased risk of intracranial aneurysm?"]
#     J --> M["Does the patient have known fibromuscular dysplasia?"]
#     J --> N["Does the patient have cranial nerve deficits?"]
#     J --> O["Does the patient have focal neurologic deficits unexplained by CT or MRI?"]
#     J --> P["Does the patient have sudden onset worst headache of life ('thunderclap')?"]
#     J --> Q["Does the patient have headache brought on by and occurring in association with exertion or Valsalva?"]
#     J --> R["Does the patient have persistent headache that meets Brain Imaging guidelines for headache and remains undifferentiated/unexplained by MRI?"]
#
#     D --> S["Is there a need for evaluation due to new or worsening neurologic symptoms?"]
#     D --> T["Is there a need for preoperative evaluation?"]
#     D --> U["Is there a need for initial postoperative evaluation?"]
#
#     E --> V["Is this the initial evaluation at 6 to 12 months following diagnosis?"]
#     E --> W["Has it been approximately one year since the last evaluation?"]
#
#     F --> X["Procedure Medically Necessary"]
#     G --> X
#     H --> X
#     I --> X
#     K --> X
#     L --> X
#     M --> X
#     N --> X
#     O --> X
#     P --> X
#     Q --> X
#     R --> X
#     S --> X
#     T --> X
#     U --> X
#     V --> X
#     W --> X
# **************************************************
# ```mermaid
# flowchart TD
#     A --> |Yes| B
#     A --> |No| C
#     B --> D
#     C --> |Yes| E
#     C --> |No| F
#     E --> D
#     F --> |Yes| G
#     F --> |No| H
#     G --> D
#     H --> |Yes| I
#     H --> |No| J
#     I --> D
#     J --> |Yes| K
#     J --> |No| L
#     K --> D
#     L --> |Yes| M
#     L --> |No| N
#     M --> D
#     N --> ["Procedure not Medically Necessary"]
#
#     A{"Does the patient have two or more first-degree relatives with intracranial aneurysm or subarachnoid hemorrhage?"}
#     B["Procedure Medically Necessary"]
#     C{"Does the patient have a condition associated with an increased risk of intracranial aneurysm (e.g., autosomal dominant polycystic kidney disease, Ehlers-Danlos syndrome type IV)?"}
#     D["Procedure Medically Necessary"]
#     E["Procedure Medically Necessary"]
#     F{"Does the patient have known fibromuscular dysplasia?"}
#     G["Procedure Medically Necessary"]
#     H{"Are there CT or MRI findings suspicious for aneurysm?"}
#     I["Procedure Medically Necessary"]
#     J{"Are there neurologic signs or symptoms (including headache) suggestive of intracranial aneurysm with at least one first degree relative with intracranial aneurysm or subarachnoid hemorrhage?"}
#     K["Procedure Medically Necessary"]
#     L{"Is there a known intracranial aneurysm requiring evaluation for progression, recurrence, preoperative or postoperative assessment?"}
#     M["Procedure Medically Necessary"]
# ```
# &&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&
# &&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&
# Error: Avascular necrosis  failed because: Graph type 'Undetermined' cannot be converted.
# **************************************************
# graph TD
#     start["Start"]
#     rg_nondiagnostic["Are radiographs nondiagnostic?"]
#     ct["Was a CT requested?"]
#     mri["Was an MRI requested?"]
#     mri_not_performable["Can an MRI not be performed?"]
#     mri_not_diag["Was an MRI non-diagnostic?"]
#     pmc["Procedure Medically Necessary"]
#     start --> rg_nondiagnostic
#     rg_nondiagnostic --> ct
#     rg_nondiagnostic --> mri
#     ct --> mri_not_performable
#     ct --> mri_not_diag
#     mri --> pmc
#     mri_not_performable --> pmc
#     mri_not_diag --> pmc
# **************************************************
# ```mermaid
# flowchart TD
#     A --> |Yes| B
#     A --> |No| C
#     B --> |Yes| D
#     B --> |No| E
#     C --> |Yes| F
#     C --> |No| G
#     E --> |Yes| H
#     E --> |No| I
#     F --> |Yes| J
#     F --> |No| K
#     H --> |Yes| L
#     H --> |No| M
#
#     A{"Are nondiagnostic radiographs available?"}
#     B{"Is MRI of upper or lower extremity possible?"}
#     C{"Is the patient at high risk for avascular necrosis?"}
#     D["MRI of upper or lower extremity: Procedure Medically Necessary"]
#     E{"Can CT of upper or lower extremity be performed?"}
#     F{"Are radiographs normal or inconclusive?"}
#     G["Procedure not Medically Necessary"]
#     H{"Is additional information needed to guide treatment?"}
#     I["Procedure not Medically Necessary"]
#     J["MRI of upper or lower extremity: Procedure Medically Necessary"]
#     K["Procedure not Medically Necessary"]
#     L["CT of upper or lower extremity: Procedure Medically Necessary"]
#     M["Procedure not Medically Necessary"]
# ```
# &&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&
# 0.5857 - Localized facial pain (including trigeminal neuralgia)
# &&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&
# graph TD
#     A["Start"] -->|True| B{"Is the facial pain localized?"}
#     B -->|True| C{"Is the facial pain persistent?"}
#     C -->|True| D{"Is the facial pain unexplained?"}
#     D -->|True| E["Procedure Medically Necessary"]
# **************************************************
# ```mermaid
# flowchart TD
#     A --> |Yes| B
#     A --> |No| C
#     B --> D
#     C --> E
#
#     A{"Is the facial pain localized,<br>persistent, and unexplained?"}
#     B["CT orbit, sella, or posterior fossa<br>and outer, middle, or inner ear<br>OR<br>MRI orbit, face, and neck (soft tissue)"]
#     C{"Is there any other indication<br>for imaging not mentioned<br>in the guideline?"}
#     D["Procedure Medically Necessary"]
#     E["Procedure not Medically Necessary"]
# ```
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# flowchart TD;
#   A["Is the facial pain localized,<br>persistent, and unexplained?"]
#   B["CT orbit, sella, or posterior fossa<br>and outer, middle, or inner ear<br>OR<br>MRI orbit, face, and neck (soft tissue)"]
#   _start_["start"]
#   _end_["end"]
#   B-->|Yes| _end_
#   _start_-->|Yes| A
#   A-->|Yes| B
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# &&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&
# 0.5517 - Hemoperitoneum
# &&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&
# graph TD
#     A["Start"] -->|True| C{"Is the evaluation for diagnosis?"}
#     A -->|True| D{"Is the evaluation for management?"}
#     C -->|True| F["Procedure Medically Necessary"]
#     D -->|True| F
# **************************************************
# ```mermaid
# flowchart TD
#     A["Is advanced imaging needed for diagnosis and management of Hemoperitoneum?"]
#     A -->|Yes| B["Is CT of abdomen and/or pelvis being considered?"]
#     A -->|No| C["Procedure not Medically Necessary"]
#     B -->|Yes| D["Procedure Medically Necessary"]
#     B -->|No| C
# ```
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# flowchart TD;
#   A["Is advanced imaging needed for diagnosis and management of Hemoperitoneum?"]
#   B["Is CT of abdomen and/or pelvis being considered?"]
#   _start_["start"]
#   _end_["end"]
#   B-->|Yes| _end_
#   _start_-->|Yes| A
#   A-->|Yes| B
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# &&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&
# &&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&
# Error: Poorly-differentiated neuroendocrine tumor failed because: Graph type 'Undetermined' cannot be converted.
# **************************************************
#
# graph TD
#     A["Start"] --> B["Is CT chest, CT abdomen and pelvis requested?"]
#     A --> C["Is MRI abdomen, MRI pelvis requested?"]
#     A --> D["Is FDG-PET/CT requested?"]
#
#     B --> E["Is the patient diagnosed with a poorly-differentiated neuroendocrine tumor (excluding lung)?"]
#     E --> F["Is this for initial staging, treatment response assessment, or surveillance?"]
#     F --> G["Procedure Medically Necessary"]
#
#     C --> H["Is the patient diagnosed with a poorly-differentiated neuroendocrine tumor (excluding lung)?"]
#     H --> I["Is this for initial staging, treatment response assessment, or surveillance?"]
#     I --> G
#
#     D --> J["Is the patient diagnosed with a poorly-differentiated neuroendocrine tumor (excluding lung)?"]
#     J --> K["Is this for initial staging?"]
#     J --> L["Is this for treatment response assessment?"]
#
#     K --> M["Can standard imaging not be performed?"]
#     K --> N["Is standard imaging nondiagnostic for metastatic disease?"]
#     M --> G
#     N --> G
#
#     L --> O["Was PET used for initial staging?"]
#     O --> G
#
# **************************************************
# ```mermaid
# flowchart TD
#     A --> |Yes| B
#     A --> |No| C
#     B --> |Yes| D
#     B --> |No| E
#     C --> |Yes| F
#     C --> |No| G
#     D --> |Yes| H
#     D --> |No| I
#     E --> |Yes| J
#     E --> |No| K
#     F --> |Yes| L
#     F --> |No| M
#     G --> |Yes| N
#     G --> |No| O
#     H --> |Yes| P
#     H --> |No| Q
#     I --> |Yes| R
#     I --> |No| S
#
#     A{"Is it a poorly differentiated neuroendocrine tumor of the lung?"}
#     B{"Refer to Small Cell Lung Cancer section?"}
#     C{"Is CT chest, CT abdomen and pelvis indicated?"}
#     D{"Is MRI abdomen and MRI pelvis indicated?"}
#     E{"Is FDG-PET/CT indicated when standard imaging cannot be performed or is nondiagnostic for metastatic disease?"}
#     F{"Is FDG-PET/CT indicated to assess treatment response when PET used for initial staging?"}
#     G{"Is it a well-differentiated neuroendocrine tumor?"}
#     H{"Is somatostatin receptor (SSR) imaging recommended for initial staging?"}
#     I{"Is SSR-PET/CT preferred over other imaging modalities?"}
#     J{"Is 68Ga DOTATATE PET superior to somatostatin receptor scintigraphy?"}
#     K{"Is 64Cu-DOTATATE non-inferior to 68Ga-DOTATATE in diagnostic accuracy?"}
#     L{"Should imaging to assess disease response be performed with the same modality used to detect the initial abnormality?"}
#     M{"Is somatostatin analog receptor imaging vital prior to PRRT?"}
#     N{"Is routine surveillance imaging recommended for poorly differentiated tumors?"}
#     O{"Should SSTR PET be used routinely for surveillance?"}
#     P{"Procedure Medically Necessary"}
#     Q{"Procedure not Medically Necessary"}
#     R{"Procedure Medically Necessary"}
#     S{"Procedure not Medically Necessary"}
# ```
# &&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&
# 0.2390 - Pancreatic Cancer
# &&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&
# graph TD
#     START["Start"]
#     CT_CHEST["Is CT chest requested?"]
#     CT_ABDOMEN["Is CT abdomen requested?"]
#     CT_PELVIS["Is CT pelvis requested?"]
#     MRI["Is MRI pelvis requested?"]
#     FDG["Is an FDG-PET/CT requested?"]
#     DIAG_MRI["Is this procedure diagnostic?"]
#     CT_CONTRA["Is a CT contraindicated?"]
#     CT_SUBOPT["Is a CT expected to be suboptimal?"]
#     CT_LIVER["Are there CT-indeterminate liver lesions?"]
#     RESECTABILITY["Is there a need to establish resectability in borderline cases?"]
#     DIAG_FDG["Is this procedure diagnostic?"]
#     DIAG_FDG_Q1["Has dedicated high-quality pancreatic imaging been performed?"]
#     DIAG_FDG_Q2["Is extra-pancreatic disease absent?"]
#     DIAG_FDG_Q3["Is CA 19-9 >100 U/ml?"]
#     DIAG_FDG_Q4["Is primary tumor >2cm?"]
#     DIAG_FDG_Q5["Are regional nodes enlarged?"]
#     DIAG_FDG_Q6["Is tumor borderline resectable?"]
#
#
#     MGMT_FDG["Is this procedure for management?"]
#     MGMT_FDG_Q1["Is this for radiation planning without distant metastasis?"]
#     MGMT_FDG_Q2["Is standard imaging nondiagnostic for recurrent/progressive disease?"]
#
#     PMC["Procedure Medically Necessary"]
#
#     START --> CT_CHEST
#     START --> CT_ABDOMEN
#     START --> CT_PELVIS
#     START --> MRI
#     START --> FDG
#
#     CT_CHEST --> PMC
#     CT_ABDOMEN --> PMC
#     CT_PELVIS --> PMC
#
#     MRI --> DIAG_MRI
#     DIAG_MRI --> CT_CONTRA
#     DIAG_MRI --> CT_SUBOPT
#     DIAG_MRI --> CT_LIVER
#     DIAG_MRI --> RESECTABILITY
#     CT_CONTRA --> PMC
#     CT_SUBOPT --> PMC
#     CT_LIVER --> PMC
#     RESECTABILITY  --> PMC
#
#     FDG --> DIAG_FDG
#     DIAG_FDG --> DIAG_FDG_Q1
#     DIAG_FDG_Q1 --> DIAG_FDG_Q2
#     DIAG_FDG_Q2 --> DIAG_FDG_Q3
#     DIAG_FDG_Q2 --> DIAG_FDG_Q4
#     DIAG_FDG_Q2 --> DIAG_FDG_Q5
#     DIAG_FDG_Q2 --> DIAG_FDG_Q6
#
#     DIAG_FDG_Q3 --> PMC
#     DIAG_FDG_Q4 --> PMC
#     DIAG_FDG_Q5 --> PMC
#     DIAG_FDG_Q6 --> PMC
#
#     FDG --> MGMT_FDG
#     MGMT_FDG --> MGMT_FDG_Q1
#     MGMT_FDG --> MGMT_FDG_Q2
#     MGMT_FDG_Q1 --> PMC
#     MGMT_FDG_Q2 --> PMC
# **************************************************
# ```mermaid
# flowchart TD
#     A["Is there documented pancreatic cancer?"]
#     A -->|Yes| B["Is diagnostic workup, management, or surveillance needed?"]
#     A -->|No| Z["Procedure not Medically Necessary"]
#     B -->|Yes| C["Is CT chest indicated?"]
#     B -->|No| Z
#     C -->|Yes| D["Is CT abdomen and pelvis indicated?"]
#     C -->|No| D
#     D -->|Yes| E["Is MRI abdomen needed for any of these reasons: CT contraindicated/suboptimal, characterization of CT-indeterminate liver lesions, or to establish resectability in borderline cases?"]
#     D -->|No| E
#     E -->|Yes| F["Is FDG-PET/CT indicated based on specific criteria?"]
#     E -->|No| F
#     F -->|Yes| G["Procedure Medically Necessary"]
#     F -->|No| G
# ```
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# flowchart TD;
#   A["Is there documented pancreatic cancer?"]
#   B["Is diagnostic workup, management, or surveillance needed?"]
#   _start_["start"]
#   _end_["end"]
#   B-->|Yes| _end_
#   _start_-->|Yes| A
#   A-->|Yes| B
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# &&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&
# 0.8683 - Tumor/Neoplasm Indeterminate bone lesion
# &&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&
# Error: Soft Tissue Sarcoma failed because: 'L'
# **************************************************
# graph TD
#     A["Start"]
#     D["Is the imaging CT or MRI of the primary site?"]
#     E["Is the imaging CT of the chest?"]
#     F["Is the imaging CT of the abdomen and pelvis?"]
#     G["Is the imaging MRI of the spine?"]
#     H["Is the imaging FDG-PET/CT?"]
#     I["Is it for diagnostic workup?"]
#     I2["Is it for diagnostic workup?"]
#     J["Is it for evaluation of suspected/known spinal metastases?"]
#     L["Is it for management?"]
#     L2["Is it for management?"]
#     M["Is standard imaging non-performable or nondiagnostic for metastatic disease?"]
#     N["Does standard imaging suggest a resectable solitary metastasis?"]
#     O["Is it a baseline study prior to neoadjuvant chemotherapy?"]
#     P["Is it for initial staging of rhabdomyosarcoma?"]
#     Q["Is it following completion of neoadjuvant chemotherapy?"]
#     R["Is standard imaging non-performable or nondiagnostic for recurrent/progressive disease?"]
#     Z["Procedure Medically Necessary"]
#     A-->D
#     D-->Z
#     A-->E
#     E-->Z
#     A-->F
#     F-->Z
#     A-->G
#     G-->I
#     I-->Z
#     G-->L
#     L-->J
#     J-->Z
#     A-->H
#     H-->I2
#     H-->L2
#     I2-->M
#     M-->Z
#     I2-->N
#     N-->Z
#     I2-->O
#     O-->Z
#     I2-->P
#     P-->Z
#     L2-->Q
#     Q-->Z
#     L2-->R
#     R-->Z
# **************************************************
# ```mermaid
# flowchart TD
#     A --> |Yes| B
#     A --> |No| C
#     B --> |Yes| D
#     B --> |No| E
#     D --> |Yes| F
#     D --> |No| G
#     F --> |Yes| H
#     F --> |No| I
#     H --> |Yes| J
#     H --> |No| K
#     J --> |Yes| L
#     J --> |No| M
#     L --> |Yes| N
#     L --> |No| O
#     N --> |Yes| P
#     N --> |No| Q
#
#     A{"Is there a documented sarcoma of bone, cartilage, connective tissue, or other soft tissue (including gastrointestinal stromal tumors)?"}
#     B{"Is advanced imaging needed for diagnostic workup, management, or surveillance?"}
#     C["Procedure not Medically Necessary"]
#     D{"Is CT or MRI of primary site indicated?"}
#     E["Procedure not Medically Necessary"]
#     F{"Is CT chest indicated?"}
#     G["Procedure not Medically Necessary"]
#     H{"Is CT abdomen and pelvis indicated?"}
#     I["Procedure not Medically Necessary"]
#     J{"Is MRI spine indicated for myxoid/round cell liposarcoma or evaluation of suspected/known spinal metastases?"}
#     K["Procedure not Medically Necessary"]
#     L{"Is FDG-PET/CT indicated for any of the following scenarios (excluding desmoid tumors):
#     1. Standard imaging cannot be performed or is nondiagnostic for metastatic disease
#     2. Standard imaging suggests a resectable solitary metastasis
#     3. Baseline study prior to neoadjuvant chemotherapy
#     4. Initial staging for rhabdomyosarcoma
#     5. Following completion of neoadjuvant chemotherapy
#     6. Standard imaging cannot be performed or is nondiagnostic for recurrent or progressive disease?"}
#     M["Procedure not Medically Necessary"]
#     N{"Is the imaging being used for diagnostic workup, management, or surveillance purposes?"}
#     O["Procedure not Medically Necessary"]
#     P["Procedure Medically Necessary"]
#     Q["Procedure not Medically Necessary"]
# ```
# &&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&
# &&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&
# Error: Retroperitoneal conditions failed because: Graph type 'Undetermined' cannot be converted.
# **************************************************
# graph TD
#     A["Start"]
#     B["Is the request for MRI Abdomen and/or Pelvis?"]
#     C["Is the request for CT abdomen and/or pelvis?"]
#     D["Is the patient a pediatric patient?"]
#     E["Can CT be performed and is it diagnostic?"]
#     F["Does the patient have Fibrosis?"]
#     G["Does the patient have Inflammation?"]
#     H["Does the patient have Bleeding?"]
#     I["Does the patient have a Mass?"]
#     J["Procedure Medically Necessary"]
#     A-->B
#     A-->C
#     B-->D
#     B-->E
#     C-->F
#     C-->G
#     C-->H
#     C-->I
#     D-->F
#     D-->G
#     D-->H
#     D-->I
#     E-->F
#     E-->G
#     E-->H
#     E-->I
#     F-->J
#     G-->J
#     H-->J
#     I-->J
# **************************************************
# flowchart TD
#     A --> |Yes| B
#     A --> |No| C
#     B --> D
#     C --> E
#     D --> |Yes| F
#     D --> |No| G
#     G --> |Yes| H
#     G --> |No| I
#
#     A{"Is there a suspected or known retroperitoneal condition?"}
#     B{"Is the condition one of the following: Fibrosis, Inflammation, Bleeding, or Mass?"}
#     C["Procedure not Medically Necessary"]
#     D{"Is the patient a pediatric patient?"}
#     E["Procedure not Medically Necessary"]
#     F{"Is MRI abdomen and/or pelvis available?"}
#     G{"Is the patient an adult?"}
#     H{"Can CT be performed and is it diagnostic?"}
#     I{"Is MRI abdomen and/or pelvis available?"}
#
#     F --> |Yes| J
#     F --> |No| K
#     H --> |Yes| L
#     H --> |No| M
#     I --> |Yes| N
#     I --> |No| O
#
#     J["Procedure Medically Necessary: MRI abdomen and/or pelvis"]
#     K["Procedure Medically Necessary: CT abdomen and/or pelvis"]
#     L["Procedure Medically Necessary: CT abdomen and/or pelvis"]
#     M["Procedure Medically Necessary: MRI abdomen and/or pelvis"]
#     N["Procedure Medically Necessary: MRI abdomen and/or pelvis"]
#     O["Procedure not Medically Necessary"]
# &&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&
# 0.5581 - Splenic mass, benign
# &&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&
# graph TD
#     A["Start"] -->|True| B{"Is there a splenic mass?"}
#     B -->|True| C{"Is the splenic mass diagnosed as benign?"}
#     C -->|True| D{"Has ultrasound been performed?"}
#     D -->|True| E{"Was the ultrasound nondiagnostic?"}
#     D -->|True| F{"Has rapid growth of the splenic mass been observed?"}
#     PMC["Procedure Medically Necessary"]
#     E --> PMC
#     F --> PMC
# **************************************************
# ```mermaid
# flowchart TD
#     A["Was ultrasound nondiagnostic or is there rapid growth?"]
#     B["Is advanced imaging needed for management?"]
#     C["Procedure Medically Necessary"]
#     D["Procedure not Medically Necessary"]
#
#     A -->|Yes| B
#     A -->|No| D
#     B -->|Yes| C
#     B -->|No| D
# ```
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# flowchart TD;
#   A["Was ultrasound nondiagnostic or is there rapid growth?"]
#   B["Is advanced imaging needed for management?"]
#   _start_["start"]
#   _end_["end"]
#   B-->|Yes| _end_
#   _start_-->|Yes| A
#   A-->|Yes| B
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# &&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&
# &&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&
# Error: Visual Disturbance failed because: The graph is not a DAG.
# **************************************************
# flowchart TD
#     A["Start"] -->B["Is there a central nervous system pathology suggested by ophthalmologic exam?"]
#     B -->C["Procedure Medically Necessary"]
# **************************************************
# ```mermaid
# flowchart TD
#     A --> |Yes| B
#     A --> |No| C
#     B --> D
#     C --> E
#
#     A{"Is there a need for evaluation of central nervous system pathology?"}
#     B{"Is this need suggested by the ophthalmologic exam?"}
#     C{"Procedure not Medically Necessary"}
#     D{"Procedure Medically Necessary"}
#     E{"Procedure not Medically Necessary"}
# ```
# &&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&
# 0.6782 - Brachial plexopathy
# 0.6339 - Congenital or developmental vascular anomalies, not otherwise specified
# 0.8548 - Constipation (Pediatric only)
# 0.4384 - Esophageal and Gastroesophageal Junction Cancers
# &&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&
# flowchart TD
#   start["Start"]
#   ct_chest["Is a CT Chest requested?"]
#   ct_abdomen["Is a CT Abdomen requested?"]
#   ct_pelvis["Is a CT Pelvis requested?"]
#   mri_chest["Is a Chest MRI requested?"]
#   mri_abdomen["Is an Abdomen MRI requested?"]
#   is_ct_contra["Is a CT contraindicated or expected to be suboptimal (due to contrast allergy or anticipated contrast nephrotoxicity)."]
#   mri_pelvis["Is a Pelvic MRI requested?"]
#   maybe_pelvic_disease["Is there clinical suspicion of pelvic disease?"]
#   maybe_pelvic_disease_mri["Is there clinical suspicion of pelvic disease?"]
#   is_ct_pelvis_contra["Is a CT contraindicated or expected to be suboptimal (due to contrast allergy or anticipated contrast nephrotoxicity)."]
#   fdg["Is an FDG PET/CT requested?"]
#   fdg_diag["Is imaging needed for a diagnostic workup?"]
#   fdg_diag_q1["Can standard imaging not be performed?"]
#   fdg_diag_q2["Does standard imaging not demonstrate distant (M1) metastatic disease?"]
#   fdg_mgmt["Is imaging needed for management?"]
#   fdg_mgmt_q1["Is the procedure for Radiation planning for preoperative or definitive treatment?"]
#   fdg_mgmt_q2["Is the procedure for Single assessment of response to chemoradiation (as definitive treatment or prior to surgery) when performed at least 5 weeks after completion of therapy?"]
#   fdg_mgmt_q3["Can Standard imaging not be performed"]
#   fdg_mgmt_q4["Is Standard imaging nondiagnostic for recurrent or progressive disease?"]
#   pmc["Procedure Medically Necessary"]
#   start --> mri_chest
#   start --> mri_abdomen
#   start --> mri_pelvis
#   mri_pelvis --> is_ct_pelvis_contra
#   is_ct_pelvis_contra --> maybe_pelvic_disease_mri
#   maybe_pelvic_disease_mri --> pmc
#   start --> ct_chest
#   start --> ct_abdomen
#   start --> ct_pelvis
#   start --> fdg
#   ct_chest --> pmc
#   ct_abdomen --> pmc
#   mri_chest --> is_ct_contra
#   mri_abdomen --> is_ct_contra
#   is_ct_contra --> pmc
#   ct_pelvis --> maybe_pelvic_disease
#   maybe_pelvic_disease --> pmc
#   fdg --> fdg_diag
#   fdg_diag --> fdg_diag_q1
#   fdg_diag --> fdg_diag_q2
#   fdg_diag_q1 --> pmc
#   fdg_diag_q2 --> pmc
#   fdg --> fdg_mgmt
#   fdg_mgmt --> fdg_mgmt_q1
#   fdg_mgmt --> fdg_mgmt_q2
#   fdg_mgmt --> fdg_mgmt_q3
#   fdg_mgmt --> fdg_mgmt_q4
#   fdg_mgmt_q1 --> pmc
#   fdg_mgmt_q2 --> pmc
#   fdg_mgmt_q3 --> pmc
#   fdg_mgmt_q4 --> pmc
# **************************************************
# ```mermaid
# flowchart TD
#     A["Is there documented esophageal or gastroesophageal junction cancer?"]
#     A -->|Yes| B["Is imaging needed for diagnostic workup, management, or surveillance?"]
#     A -->|No| Z["Procedure not Medically Necessary"]
#     B -->|Yes| C["Is CT chest or CT abdomen needed?"]
#     B -->|No| Z
#     C -->|Yes| D["Procedure Medically Necessary"]
#     C -->|No| E["Is CT pelvis needed based on clinical suspicion for pelvic disease?"]
#     E -->|Yes| D
#     E -->|No| F["Is FDG-PET/CT needed and standard imaging cannot be performed or doesn't demonstrate distant metastatic disease?"]
#     F -->|Yes| D
#     F -->|No| G["Is FDG-PET/CT needed for radiation planning for preoperative or definitive treatment?"]
#     G -->|Yes| D
#     G -->|No| H["Is FDG-PET/CT needed for single assessment of response to chemoradiation at least 5 weeks after completion of therapy?"]
#     H -->|Yes| D
#     H -->|No| I["Is FDG-PET/CT needed because standard imaging cannot be performed or is nondiagnostic for recurrent or progressive disease?"]
#     I -->|Yes| D
#     I -->|No| J["Is MRI needed and CT is contraindicated or expected to be suboptimal?"]
#     J -->|Yes| D
#     J -->|No| Z
# ```
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# flowchart TD;
#   A["Is there documented esophageal or gastroesophageal junction cancer?"]
#   B["Is imaging needed for diagnostic workup, management, or surveillance?"]
#   C["Is CT chest or CT abdomen needed?"]
#   E["Is CT pelvis needed based on clinical suspicion for pelvic disease?"]
#   F["Is FDG-PET/CT needed and standard imaging cannot be performed or doesn't demonstrate distant metastatic disease?"]
#   G["Is FDG-PET/CT needed for radiation planning for preoperative or definitive treatment?"]
#   H["Is FDG-PET/CT needed for single assessment of response to chemoradiation at least 5 weeks after completion of therapy?"]
#   I["Is FDG-PET/CT needed because standard imaging cannot be performed or is nondiagnostic for recurrent or progressive disease?"]
#   J["Is MRI needed and CT is contraindicated or expected to be suboptimal?"]
#   _start_["start"]
#   _end_["end"]
#   G-->|Yes| A
#   E-->|Yes| A
#   F-->|Yes| A
#   I-->|Yes| A
#   _start_-->|Yes| C
#   H-->|Yes| A
#   C-->|Yes| A
#   J-->|Yes| A
#   B-->|Yes| _end_
#   _start_-->|Yes| J
#   _start_-->|Yes| H
#   A-->|Yes| B
#   _start_-->|Yes| G
#   _start_-->|Yes| I
#   _start_-->|Yes| E
#   _start_-->|Yes| F
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# &&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&
# 0.2501 - Inflammatory conditions – not otherwise specified
# &&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&
# graph TD
#     A["Start"] -->B["Procedure Medically Necessary"]
# **************************************************
# flowchart TD
#     [Is advanced imaging being considered for diagnosis and management of inflammatory conditions?] --> |Yes| [Is the condition Wegener's granulomatosis, granulomatosis with polyangiitis, or neuromyelitis optica spectrum disorders?]
#     [Is the condition Wegener's granulomatosis, granulomatosis with polyangiitis, or neuromyelitis optica spectrum disorders?] --> |Yes| [Is one of the following imaging studies being considered: CT orbit, sella, or posterior fossa and outer, middle, or inner ear; MRI orbit, face, and neck (soft tissue); CT paranasal sinuses and maxillofacial area; CT soft tissue neck; or MRI temporomandibular joint for suspected inflammatory arthritis?]
#     [Is one of the following imaging studies being considered: CT orbit, sella, or posterior fossa and outer, middle, or inner ear; MRI orbit, face, and neck (soft tissue); CT paranasal sinuses and maxillofacial area; CT soft tissue neck; or MRI temporomandibular joint for suspected inflammatory arthritis?] --> |Yes| [For MRI temporomandibular joint, is it for suspected inflammatory arthritis, including juvenile idiopathic arthritis (JIA)?]
#     [For MRI temporomandibular joint, is it for suspected inflammatory arthritis, including juvenile idiopathic arthritis (JIA)?] --> |Yes| [Have initial radiographs been performed?]
#     [Have initial radiographs been performed?] --> |Yes| ["Procedure Medically Necessary"]
#     [Have initial radiographs been performed?] --> |No| ["Procedure not Medically Necessary"]
#     [For MRI temporomandibular joint, is it for suspected inflammatory arthritis, including juvenile idiopathic arthritis (JIA)?] --> |No| ["Procedure Medically Necessary"]
#     [Is one of the following imaging studies being considered: CT orbit, sella, or posterior fossa and outer, middle, or inner ear; MRI orbit, face, and neck (soft tissue); CT paranasal sinuses and maxillofacial area; CT soft tissue neck; or MRI temporomandibular joint for suspected inflammatory arthritis?] --> |No| ["Procedure not Medically Necessary"]
#     [Is the condition Wegener's granulomatosis, granulomatosis with polyangiitis, or neuromyelitis optica spectrum disorders?] --> |No| ["Procedure not Medically Necessary"]
#     [Is advanced imaging being considered for diagnosis and management of inflammatory conditions?] --> |No| ["Procedure not Medically Necessary"]
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# flowchart TD;
#   _start_["start"]
#   _end_["end"]
#   flowchart["flowchart"]
#   _start_-->|Yes| flowchart
#   flowchart-->|Yes| _end_
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# &&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&
# 0.3538 - Sacroiliitis, not otherwise specified
# &&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&
# graph TD
#     A["Start"] --> B{"Is CT or MRI pelvis requested for sacroiliitis?"}
#     B -->|Yes| C{"Have pelvic or sacral radiographs been performed?"}
#     C -->|Yes| D{"Does the patient have a condition predisposing to sacroiliitis?"}
#     C -->|Yes| E{"Are radiographs equivocal for sacroiliitis?"}
#     D -->|Yes| F{"Are radiographs negative or equivocal for sacroiliitis?"}
#     F -->|Yes| G["Procedure Medically Necessary"]
#     E -->|Yes| G
# **************************************************
# flowchart TD
#     [Have pelvic or sacral radiographs been performed?] --> |Yes| [Are radiographs negative or equivocal for sacroiliitis?]
#     [Have pelvic or sacral radiographs been performed?] --> |No| [Procedure not Medically Necessary]
#     [Are radiographs negative or equivocal for sacroiliitis?] --> |Yes| [Is there a condition predisposing to sacroiliitis?]
#     [Are radiographs negative or equivocal for sacroiliitis?] --> |No| [Procedure not Medically Necessary]
#     [Is there a condition predisposing to sacroiliitis?] --> |Yes| [Procedure Medically Necessary]
#     [Is there a condition predisposing to sacroiliitis?] --> |No| [Are radiographs specifically equivocal for sacroiliitis?]
#     [Are radiographs specifically equivocal for sacroiliitis?] --> |Yes| [Procedure Medically Necessary]
#     [Are radiographs specifically equivocal for sacroiliitis?] --> |No| [Procedure not Medically Necessary]
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# flowchart TD;
#   _start_["start"]
#   _end_["end"]
#   flowchart["flowchart"]
#   _start_-->|Yes| flowchart
#   flowchart-->|Yes| _end_
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# &&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&
# &&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&
# Error: Appendicitis failed because: 'K'
# **************************************************
# flowchart TD
#     Start["Start"]
#     Start --> IsCT{"Is the requested procedure CT Abdomen and Pelvis?"}
#     Start --> IsMRI{"Is the requested procedure MRI Abdomen and Pelvis?"}
#     Start --> IsUS{"Is the requested procedure Ultrasound?"}
#
#     IsCT -->|Yes| CTAdult{"Is patient an adult?"}
#     CTAdult -->|Yes| CTNonPreg{"Is pregnancy ruled out?"}
#     CTNonPreg -->|Yes| CTInd1{"Does patient have suspected appendicitis?"}
#     CTNonPreg -->|Yes| CTInd2{"Is imaging needed for perioperative management?"}
#     CTInd1 -->|Yes| Approve["Approve"]
#     CTInd2 -->|Yes| Approve
#
#     CTAdult -->|No| CTPreg{"Is patient pregnant?"}
#     CTPreg -->|Yes| CTPreg2{"Was ultrasound nondiagnostic?"}
#     CTPreg2 -->|Yes| CTPreg3{"Is Magnetic Resonance Imaging contraindicated?"}
#     CTPreg2 -->|Yes| CTPreg4{"Is Magnetic Resonance Imaging unavailable?"}
#     CTPreg3 -->|Yes| CTPreg5{"Does patient have suspected appendicitis?"}
#     CTPreg3 -->|Yes| CTPreg6{"Is imaging needed for perioperative management?"}
#     CTPreg4 -->|Yes| CTPreg5
#     CTPreg4 -->|Yes| CTPreg6
#     CTPreg5 -->|Yes| Approve
#     CTPreg6 -->|Yes| Approve
#
#     CTPreg -->|No| CTPed{"Is patient under 18 years old?"}
#     CTPed -->|Yes| CTPed2{"Was ultrasound attempted but failed?"}
#     CTPed -->|Yes| CTPed3{"Was ultrasound nondiagnostic?"}
#     CTPed2 -->|Yes| CTPed4{"Does patient have suspected appendicitis?"}
#     CTPed2 -->|Yes| CTPed5{"Is imaging needed for perioperative management?"}
#     CTPed3 -->|Yes| CTPed4
#     CTPed3 -->|Yes| CTPed5
#     CTPed4 -->|Yes| Approve
#     CTPed5 -->|Yes| Approve
#
#     IsMRI -->|Yes| MRIPreg{"Is patient pregnant?"}
#     MRIPreg -->|Yes| MRIPreg2{"Was ultrasound nondiagnostic?"}
#     MRIPreg2 -->|Yes| MRIInd1{"Does patient have suspected appendicitis?"}
#     MRIPreg2 -->|Yes| MRIInd2{"Is imaging needed for perioperative management?"}
#     MRIInd1 -->|Yes| Approve
#     MRIInd2 -->|Yes| Approve
#
#     MRIPreg -->|No| MRIPed{"Is patient under 18 years old?"}
#     MRIPed -->|Yes| MRIPed2{"Was ultrasound attempted but failed?"}
#     MRIPed -->|Yes| MRIPed3{"Was ultrasound nondiagnostic?"}
#     MRIPed2 -->|Yes| MRIPed4{"Does patient have suspected appendicitis?"}
#     MRIPed2 -->|Yes| MRIPed5{"Is imaging needed for perioperative management?"}
#     MRIPed3 -->|Yes| MRIPed4
#     MRIPed3 -->|Yes| MRIPed5
#     MRIPed4 -->|Yes| Approve
#     MRIPed5 -->|Yes| Approve
#
#     IsUS -->|Yes| USPreg{"Is patient pregnant?"}
#     USPreg -->|Yes| USPreg2{"Is this initial imaging?"}
#     USPreg2 -->|Yes| USInd1{"Does patient have suspected appendicitis?"}
#     USPreg2 -->|Yes| USInd2{"Is imaging needed for perioperative management?"}
#     USInd1 -->|Yes| Approve
#     USInd2 -->|Yes| Approve
#
#     USPreg -->|No| USPed{"Is patient under 18 years old?"}
#     USPed -->|Yes| USPed2{"Is this initial imaging?"}
#     USPed2 -->|Yes| USPed3{"Does patient have suspected appendicitis?"}
#     USPed2 -->|Yes| USPed4{"Is imaging needed for perioperative management?"}
#     USPed3 -->|Yes| Approve
#     USPed4 -->|Yes| Approve
# **************************************************
# ```mermaid
# flowchart TD
#     A --> |Yes| B
#     A --> |No| C
#     B --> D
#     C --> D
#     D --> |Yes| E
#     D --> |No| F
#     E --> |Yes| G
#     E --> |No| H
#     F --> |Yes| I
#     F --> |No| J
#     G --> K
#     H --> |Yes| L
#     H --> |No| M
#     I --> |Yes| N
#     I --> |No| O
#     J --> |Yes| P
#     J --> |No| Q
#     K --> ["Procedure Medically Necessary"]
#     L --> |Yes| R
#     L --> |No| S
#     M --> ["Procedure not Medically Necessary"]
#     N --> |Yes| T
#     N --> |No| U
#     O --> ["Procedure not Medically Necessary"]
#     P --> |Yes| V
#     P --> |No| W
#     Q --> ["Procedure not Medically Necessary"]
#     R --> ["Procedure Medically Necessary"]
#     S --> ["Procedure not Medically Necessary"]
#     T --> ["Procedure Medically Necessary"]
#     U --> ["Procedure Medically Necessary"]
#     V --> ["Procedure Medically Necessary"]
#     W --> |Yes| X
#     W --> |No| Y
#     X --> ["Procedure Medically Necessary"]
#     Y --> ["Procedure not Medically Necessary"]
#
# ...
# &&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&
# Error: Intra-cardiac and para-cardiac masses and tumors failed because: Graph type 'Undetermined' cannot be converted.
# **************************************************
#
# graph TD
#     A["Start"]
#     B["Is Cardiac MRI requested?"]
#     C["Is there a suspected cardiac or para-cardiac mass?"]
#     D["Is it suggested by transthoracic echocardiography?"]
#     E["Is it suggested by transesophageal echocardiography?"]
#     F["Is it suggested by blood pool imaging?"]
#     G["Is it suggested by contrast ventriculography?"]
#     H["Has the patient NOT undergone cardiac MRI or cardiac CT within the preceding 60 days?"]
#     I["Is there an established cardiac or para-cardiac mass?"]
#     J["Is the patient clinically unstable?"]
#     K["Has the patient NOT undergone cardiac MRI or cardiac CT within the preceding year?"]
#     L["Has the patient undergone treatment within the preceding year?"]
#     M["Has the patient NOT had cardiac MRI or cardiac CT within the preceding 60 days?"]
#     N["Procedure Medically Necessary"]
#
#     A --> B
#     B --> C
#     C --> D
#     C --> E
#     C --> F
#     C --> G
#     D --> H
#     E --> H
#     F --> H
#     G --> H
#     H --> N
#     B --> I
#     I --> J
#     J --> N
#     I --> K
#     K --> N
#     I --> L
#     L --> M
#     M --> N
#
# **************************************************
# ```mermaid
# flowchart TD
#     [A{"Is there a suspected cardiac or para-cardiac mass suggested by other imaging methods?"}] --> |Yes| [B{"Has the patient undergone cardiac CT or MRI within the last 60 days?"}]
#     B --> |No| [C["Procedure Medically Necessary"]]
#     B --> |Yes| [D{"Is there an established cardiac or para-cardiac mass?"}]
#     A --> |No| D
#     D --> |Yes| [E{"Is the patient clinically unstable?"}]
#     E --> |Yes| C
#     E --> |No| [F{"Has the patient undergone cardiac CT or MRI within the last year?"}]
#     F --> |No| C
#     F --> |Yes| [G{"Has the patient undergone treatment within the last year?"}]
#     G --> |Yes| [H{"Has the patient had cardiac CT or MRI within the last 60 days?"}]
#     H --> |No| C
#     H --> |Yes| [I["Procedure not Medically Necessary"]]
#     G --> |No| I
#     D --> |No| I
# ```
# &&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&
# &&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&
# Error: Chronic lymphocytic leukemia or small lymphocytic lymphoma failed because: Graph type 'Undetermined' cannot be converted.
# **************************************************
# flowchart TD
#   A["Start"]
#   B["Is the request for CT chest?"]
#   C["Is the request for CT abdomen and pelvis?"]
#   D["Is this for diagnostic workup?"]
#   E["Is this for management of a known condition?"]
#   F["Is this for surveillance?"]
#   G["Is the patient experiencing symptoms?"]
#   H["Is this to evaluate bulky disease?"]
#   I["Is the request for a MRI?"]
#   J["Is CT containdicated or expected to be suboptimal (due to contrast allergy or contrast nephrotoxicity)?"]
#   K["Is the request for a FDG-PET/CT?"]
#   L["Is this for diagnostic workup?"]
#   M["Is this for management of a known condition?"]
#   N["Is there a suspicion of Richter's transformation?"]
#   O["Is PET utilized to direct biopsy?"]
#   Z["Procedure Medically Necessary"]
#
#   A-->B
#   A-->C
#   B-->D
#   C-->D
#   D-->Z
#   B-->E
#   C-->E
#   B-->F
#   C-->F
#   E-->G
#   E-->H
#   F-->G
#   F-->H
#   G-->Z
#   H-->Z
#   A-->I
#   I-->J
#   J-->D
#   J-->E
#   J-->F
#   A-->K
#   K-->L
#   K-->M
#   L-->N
#   M-->N
#   N-->O
#   O-->Z
# **************************************************
# ```mermaid
# flowchart TD
#     A --> |Yes| B
#     A --> |No| C
#     B --> |Yes| D
#     B --> |No| E
#     C --> |Yes| F
#     C --> |No| G
#     D --> |Yes| H
#     D --> |No| I
#     E --> |Yes| J
#     E --> |No| K
#     F --> L
#     G --> M
#     H --> N
#     I --> O
#     J --> P
#     K --> Q
#
#     A{"Is CT chest, abdomen, and pelvis indicated based on symptoms or to evaluate bulky disease?"}
#     B{"Is there suspicion of Richter's transformation?"}
#     C{"Is CT contraindicated or expected to be suboptimal?"}
#     D{"Is PET utilized to direct biopsy?"}
#     E{"Is MRI medically necessary based on criteria?"}
#     F{"Is MRI indicated based on symptoms or to evaluate bulky disease?"}
#     G{"Is routine imaging necessary for monitoring treatment response or progression?"}
#     H{"Procedure Medically Necessary"}
#     I{"Procedure not Medically Necessary"}
#     J{"Procedure Medically Necessary"}
#     K{"Procedure not Medically Necessary"}
#     L{"Procedure Medically Necessary"}
#     M{"Procedure not Medically Necessary"}
#     N{"Procedure Medically Necessary"}
#     O{"Procedure not Medically Necessary"}
#     P{"Procedure Medically Necessary"}
#     Q{"Procedure not Medically Necessary"}
# ```
# &&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&
# &&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&
# Error: Sports hernia (athletic pubalgia) failed because: The graph is not a DAG.
# **************************************************
#
# graph TD
#     A["Start"] --> B["Is MRI Pelvis for Sports Hernia requested?"]
#     B -->|Yes| C["Is the pain insidious, progressive, and worsens with Valsalva or movement?"]
#     C -->|Yes| D["Is there no detectable inguinal or ventral hernia on exam?"]
#     D -->|Yes| E["Has the pain persisted for at least 6 weeks?"]
#     E -->|Yes| F["Are radiographs nondiagnostic?"]
#     F -->|Yes| G["Have symptoms not improved following at least 6 weeks of conservative therapy?"]
#     G -->|Yes| H["Is the patient a surgical candidate?"]
#     H -->|Yes| I["Procedure Medically Necessary"]
#
# **************************************************
# ```mermaid
# flowchart TD
#     A --> |Yes| B
#     A --> |No| Z
#     B --> |Yes| C
#     B --> |No| Z
#     C --> |Yes| D
#     C --> |No| Z
#     D --> |Yes| E
#     D --> |No| Z
#     E --> |Yes| F
#     E --> |No| Z
#     F --> |Yes| G
#     F --> |No| Z
#     G --> H
#     Z --> Y
#
#     A{"Is pain insidious, progressive, and worsens with Valsalva or movement?"}
#     B{"Is there no detectable inguinal or ventral hernia on exam?"}
#     C{"Has pain persisted for at least 6 weeks?"}
#     D{"Are radiographs nondiagnostic?"}
#     E{"Have symptoms not improved following at least 6 weeks of conservative therapy?"}
#     F{"Is the patient a surgical candidate?"}
#     G{"MRI pelvis"}
#     H{"Procedure Medically Necessary"}
#     Y{"Procedure not Medically Necessary"}
#     Z{"Procedure not Medically Necessary"}
# ```
# &&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&
# 0.5935 - Other thoracic mass lesions
# &&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&
# flowchart TD
#   A["start"]
#   B["Is the patient an adult?"]
#   C["Is the patient pediatric?"]
#   D["Is the request for CT chest?"]
#   E["Is the request for MRI chest?"]
#   F["Is the request for evaluation of mediastinal and hilar masses?"]
#   G["Is CT insufficient for problem solving?"]
#   H["Is the request for evaluation of chest wall extension in Pancoast tumor?"]
#   I["Does the patient have mediastinal mass?"]
#   J["Does the patient have pancoast tumor?"]
#   K["Does the patient have pleural mass?"]
#   L["Does the patient have thymoma?"]
#   M["Does the patient have benign tumors?"]
#   N["Medically Necessary"]
#   A-->B
#   A-->C
#   B-->D
#   B-->E
#   E-->F
#   F-->G
#   E-->H
#   D-->I
#   G-->I
#   H-->I
#   C-->I
#   D-->J
#   G-->J
#   H-->J
#   C-->J
#   D-->K
#   G-->K
#   H-->K
#   C-->K
#   D-->L
#   G-->L
#   H-->L
#   C-->L
#   C-->M
#   I-->N
#   J-->N
#   K-->N
#   L-->N
#   M-->N
# **************************************************
# ```mermaid
# flowchart TD
#     A["Is there a mediastinal mass?"] -->|Yes| B["Procedure Medically Necessary"]
#     A -->|No| C["Is there a Pancoast tumor?"]
#     C -->|Yes| B
#     C -->|No| D["Is there a pleural mass?"]
#     D -->|Yes| B
#     D -->|No| E["Is there a thymoma?"]
#     E -->|Yes| B
#     E -->|No| F["Is the patient pediatric?"]
#     F -->|No| G["Procedure not Medically Necessary"]
#     F -->|Yes| H["Is there a benign tumor?"]
#     H -->|Yes| B
#     H -->|No| G
# ```
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# flowchart TD;
#   A["Is there a mediastinal mass?"]
#   C["Is there a Pancoast tumor?"]
#   D["Is there a pleural mass?"]
#   E["Is there a thymoma?"]
#   F["Is the patient pediatric?"]
#   H["Is there a benign tumor?"]
#   _start_["start"]
#   _end_["end"]
#   _start_-->|Yes| A
#   C-->|Yes| _end_
#   _start_-->|Yes| D
#   F-->|Yes| H
#   _start_-->|Yes| C
#   H-->|Yes| _end_
#   E-->|Yes| _end_
#   D-->|Yes| _end_
#   _start_-->|Yes| E
#   _start_-->|Yes| F
#   A-->|Yes| _end_
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# &&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&
# 0.6982 - Ovarian Cancer – All Variants > FDG-PET/CT
# 0.7067 - Bladder or urethral diverticula
# &&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&
# Error: Non-specific mid-back pain (thoracic) failed because: Graph type 'Undetermined' cannot be converted.
# **************************************************
#
# graph TD
#     A["Start"] --> B["Is MRI Thoracic Spine for Adult requested?"]
#     A --> C["Is CT Thoracic Spine for Adult requested?"]
#     A --> D["Is MRI Thoracic Spine for Pediatric requested?"]
#     A --> E["Is CT Thoracic Spine for Pediatric requested?"]
#
#     B --> F["Is the patient an adult?"]
#     F --> G["Is the patient a potential candidate for spine intervention?"]
#     G --> H["Does the patient have pain with neurologic findings suggesting thoracic or lumbar nerve root or cord compression that has not previously been imaged?"]
#     G --> I["Does the patient have pain with neurologic findings suggesting thoracic or lumbar nerve root or cord compression that has progressed since imaging was performed?"]
#     G --> J["Does the patient have pain without a neurologic component that has not responded to at least 6 weeks of conservative management?"]
#
#     C --> K["Is the patient an adult?"]
#     K --> L["Is the patient a potential candidate for spine intervention?"]
#     L --> P["Is MRI unable to be performed or has it been nondiagnostic?"]
#     P --> M["Does the patient have pain with neurologic findings suggesting thoracic or lumbar nerve root or cord compression that has not previously been imaged?"]
#     P --> N["Does the patient have pain with neurologic findings suggesting thoracic or lumbar nerve root or cord compression that has progressed since imaging was performed?"]
#     P --> O["Does the patient have pain without a neurologic component that has not responded to at least 6 weeks of conservative management?"]
#
#     D --> Q["Is the patient a child?"]
#     Q --> R["Does the patient have localized or radicular pain not explained by radiograph and not responsive to a course of conservative management?"]
#     Q --> S["Does the patient have pain with evidence of nerve root or cord compression?"]
#
#     E --> T["Is the patient a child?"]
#     T --> W["Is MRI unable to be performed or has it been nondiagnostic?"]
#     W --> U["Does the patient have localized or radicular pain not explained by radiograph and not responsive to a course of conservative management?"]
#     W --> V["Does the patient have pain with evidence of nerve root or cord compression?"]
#
#     H --> X["Procedure Medically Necessary"]
#     I --> X
#     J --> X
#     M --> X
#     N --> X
#     O --> X
#     P --> X
#     R --> X
#     S --> X
#     U --> X
#     V --> X
#     W --> X
#
# **************************************************
# ```mermaid
# flowchart TD
#     A --> |Yes| B
#     A --> |No| C
#     B --> |Yes| D
#     B --> |No| E
#     C --> |Yes| F
#     C --> |No| G
#     D --> H
#     E --> I
#     F --> J
#     G --> |Yes| K
#     G --> |No| L
#     H --> M
#     I --> N
#     J --> O
#     K --> P
#     L --> Q
#
#     A{"Is the patient an adult?"}
#     B{"Does the patient have pain with neurologic findings suggesting thoracic or lumbar nerve root or cord compression that has not previously been imaged or has progressed since imaging was performed?"}
#     C{"Is the patient pediatric?"}
#     D{"Is the patient a potential candidate for spine intervention?"}
#     E{"Does the patient have pain without a neurologic component that has not responded to at least 6 weeks of conservative management?"}
#     F{"Does the patient have localized or radicular pain not explained by radiograph and not responsive to a course of conservative management?"}
#     G{"Does the patient have pain with evidence of nerve root or cord compression?"}
#     H{"Procedure Medically Necessary"}
#     I{"Is the patient a potential candidate for spine intervention?"}
#     J{"Procedure Medically Necessary"}
#     K{"Procedure Medically Necessary"}
#     L{"Procedure not Medically Necessary"}
#     M{"MRI thoracic spine or CT thoracic spine (excluding CT discography) when MRI cannot be performed or is nondiagnostic"}
#     N{"Procedure Medically Necessary"}
#     O{"MRI thoracic spine or CT thoracic spine (excluding CT discography) when MRI cannot be performed or is nondiagnostic"}
#     P{"MRI thoracic spine or CT thoracic spine (excluding CT discography) when MRI cannot be performed or is nondiagnostic"}
#     Q{"Procedure not Medically Necessary"}
# ```
# &&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&
# &&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&
# Error: Stenosis or occlusion of the abdominal aorta or branch vessels, not otherwise specified failed because: 'A'
# **************************************************
#
# graph TD
#     A["Start"] --> B["Is vascular imaging requested for diagnosis of suspected aortoiliac stenosis or occlusion?"]
#     A --> C["Is vascular imaging requested for management of known stenosis?"]
#     A --> D["Is vascular imaging requested for surveillance?"]
#
#     B --> E["Is there an abdominal or femoral bruit?"]
#     B --> F["Is there a decreased or absent femoral pulse?"]
#     B --> G["Does the patient experience atypical lower extremity claudication?"]
#     B --> H["Does the patient present with Leriche's syndrome?"]
#     B --> I["Is there evidence of atheroembolic disease of the lower extremities?"]
#     B --> J["Does physiological testing suggest aorto-iliac disease?"]
#     B --> K["Is there an established femoral or popliteal artery aneurysm?"]
#
#     C --> L["Is this a presurgical evaluation of aortoiliac stenosis or occlusion where intervention is being considered?"]
#
#     D --> M["Is this an annual surveillance of surgical bypass grafts?"]
#
#     E --> N["Procedure Medically Necessary"]
#     F --> N
#     G --> N
#     H --> N
#     I --> N
#     J --> N
#     K --> N
#     L --> N
#     M --> N
#
# **************************************************
# ```mermaid
# flowchart TD
#     A --> |Yes| B
#     A --> |No| C
#     B --> D
#     C --> |Yes| D
#     C --> |No| E
#     E --> |Yes| D
#     E --> |No| F
#
#     A{"Is there a suspected diagnosis of aortoiliac stenosis or occlusion based on ANY of the following:
#     - Abdominal or femoral bruit
#     - Decreased or absent femoral pulse
#     - Atypical lower extremity claudication
#     - Leriche's syndrome
#     - Evidence of atheroembolic disease of lower extremities
#     - Physiological testing suggesting aorto-iliac disease
#     - Established femoral or popliteal artery aneurysm?"}
#     B["Procedure Medically Necessary"]
#     C{"Is there a need for presurgical evaluation of aortoiliac stenosis or occlusion when endovascular or surgical intervention is being considered?"}
#     D["Imaging study: Duplex arterial ultrasound, CTA abdomen and/or pelvis, or MRA abdomen and/or pelvis"]
#     E{"Is there a need for annual surveillance of surgical bypass grafts?"}
#     F["Procedure not Medically Necessary"]
# ```
# &&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&
# 0.6369 - Neck mass (including lymphadenopathy)
# 42
# 25

# %%
print("CLAUDE")
print(score_total)
print(score_total / count)
print(score_total / match_count)
# Out:
# CLAUDE
# 14.677060878508822
# 0.34945383044068623
# 0.5870824351403529

# %%
print("gpt-4o-latest")
print(score_total)
print(score_total / count)
print(score_total / match_count)
# Out:
# gpt-4o-latest
# 14.677060878508822
# 0.34945383044068623
# 0.5870824351403529
